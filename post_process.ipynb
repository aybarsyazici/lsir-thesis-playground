# %%
from dotenv import load_dotenv
import os
from post_processing_newest import semantic_search, fetch_wikidata_info, fast_clustering, agglomerative_clustering
from pathlib import Path
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from transformers import AutoModel
import torch
load_dotenv()

data_path = Path("/home/yazici/playground/new-prompts/output/gpt-4o-2024-08-06_event2_newest_report_20241107-035313.json")
anchor_file_path = Path("/mnt/datasets/dop-position-mining/wiki-anchor/anchor_target_counts.csv")
# Out:
# /home/yazici/.cache/pypoetry/virtualenvs/new-prompts-cm8HmoVy-py3.9/lib/python3.9/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:13: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange

# %%
df = pd.read_json(data_path)
device = "cuda:1" if torch.cuda.is_available() else "cpu"

# %%
batch_size = 64 * 4 if device == "cuda" else 64
# Explode the 'positions' field if it contains a list
df_report = df.explode("positions").reset_index(drop=True)

# Normalize the 'positions' field into a separate dataframe
df_positions = pd.json_normalize(df_report["positions"])
# drop rows that have the targets as empty lists
df_positions = df_positions[df_positions["targets"].apply(len) > 0]
# --- Stakeholder Clustering ---
print(
    f"{len(df_positions['stakeholder'].unique())} stakeholders"
    " before clustering..."
)
stakeholders = df_positions["stakeholder"].tolist()
stakeholders = [stakeholder.lower().strip() for stakeholder in stakeholders]
# does df_max_views.parquet exist?
anchor_file_path_dir = Path(anchor_file_path).parent
if (anchor_file_path_dir / "df_max_views.parquet").exists():
    print("Anchor file found.")
    df_max_views = pd.read_parquet(anchor_file_path_dir / "df_max_views.parquet")
    df_embeddings = [
        torch.stack([torch.tensor(emb) for emb in df_max_views["jina_embeddings"].values]),
        torch.stack([torch.tensor(emb) for emb in df_max_views["sentence_transformer_embeddings"].values]),
    ]
else:
    raise FileNotFoundError("Anchor file not found.")
# Out:
# 3836 stakeholders before clustering...
# Anchor file found.

# %%
df_max_views.head()
# Out:
#         normalized_anchor_text  target_page_id  target_item_id  \
# 364147                       !           10606          120976
# 743613                     !!!          600744             371
# 743614       !!! (chk chk chk)          600744             371
# 743615         !!! chk chk chk          600744             371
# 4602208         !!!fuck you!!!         4838455         1106400
#
#         target_page_title  target_page_views  anchor_target_count  \
# 364147          Factorial              30517                   28
# 743613                !!!               3428                  108
# 743614                !!!               3428                    4
# 743615                !!!               3428                    3
# 4602208     Fuck You (EP)                362                    4
#
#          p_anchor_given_target  p_target_given_anchor  \
# 364147                0.074271               0.459016
# 743613                0.923077               1.000000
# 743614                0.034188               1.000000
# 743615                0.025641               1.000000
# 4602208               1.000000               1.000000
#
#                                            jina_embeddings  \
# 364147   [0.120287396, -0.17119974, 0.018252913, 0.0800...
# 743613   [0.11590401, -0.16914222, 0.025198031, 0.08789...
# 743614   [0.14810045, -0.098733634, 0.04295554, 0.09873...
# 743615   [0.12620306, -0.11048431, 0.031981107, 0.10473...
# 4602208  [0.06759844, -0.12256393, 0.030473959, 0.01470...
#
#                            sentence_transformer_embeddings
# 364147   [-0.04682187, 0.028049402, -0.04723211, 0.1036...
# 743613   [-0.04671332, 0.05583068, -0.05227658, 0.00920...
# 743614   [0.0060914885, 0.021325106, -0.014094437, 0.02...
# 743615   [-0.015853163, 0.021743488, -0.015280079, -0.0...
# 4602208  [-0.031093562, 0.01322756, -0.036412507, -0.02...

# %%
import pickle
from tqdm import tqdm
from typing import List, Tuple

# stakeholders: List[str],
# df_embeddings: List[torch.Tensor],
# device: str,
# df_max_views: pd.DataFrame,
# models: Tuple[AutoModel, SentenceTransformer] = None,
# threshold=0.15,
# clustering_method="fast",
# output_dir=None,
# event_name="",

models = (
    AutoModel.from_pretrained(
        "arkohut/jina-embeddings-v3", trust_remote_code=True
    ).to(device),
    SentenceTransformer("all-mpnet-base-v2", device=device),
)
threshold = 0.15
clustering_method = "fast"
output_dir = Path("/home/yazici/playground/new-prompts/temp-files")
# output_dir = None
event_name = "event2_multimodel"
# Out:
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.
# flash_attn is not installed. Using PyTorch native attention implementation.

# %%
assert len(df_embeddings) == 2, "Two models are required for wiki_anchor"
assert df_embeddings[0].shape[1] == 1024, "Model 1 should output 1024 dim embeddings"
assert df_embeddings[1].shape[1] == 768, "Model 2 should output 768 dim embeddings"
batch_size = 64 * 4 if device == "cuda" else 64
unique_stakeholders = list(set(stakeholders))

# %%
if models is None:
    models = (
        AutoModel.from_pretrained(
            "arkohut/jina-embeddings-v3", trust_remote_code=True
        ).to(device),
        SentenceTransformer("all-mpnet-base-v2", device=device),
    )
# Initial wiki matches
unique_stakeholder_embeddings = (
    models[0].encode(
        unique_stakeholders,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    ),
    models[1].encode(
        unique_stakeholders,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    )
)
search_results = (
    semantic_search(
        unique_stakeholder_embeddings[0],  # query embeddings
        df_embeddings[0],  # database embeddings (can remain on CPU)
        top_k=1,  # Retrieve the top match only, adjust as needed
        device=device,
    ),
    semantic_search(
        unique_stakeholder_embeddings[1],  # query embeddings
        df_embeddings[1],  # database embeddings (can remain on CPU)
        top_k=1,  # Retrieve the top match only, adjust as needed
        device=device,
    )
)

del unique_stakeholder_embeddings
# Out:
# Encoding:   0%|          | 0/60 [00:00<?, ?it/s]
# Batches:   0%|          | 0/60 [00:00<?, ?it/s]
# Query chunks: 100%|██████████| 39/39 [03:35<00:00,  5.53s/it]
# Query chunks: 100%|██████████| 39/39 [02:41<00:00,  4.13s/it]

# %%
from collections import defaultdict
# Process search results to get the best matches above the threshold
all_results = {}
stakeholder_index_to_target_item_id = [None] * len(stakeholders)

for idx in range(len(unique_stakeholders)):
    best_match_model1 = search_results[0][idx][0]
    best_match_model2 = search_results[1][idx][0]
    if best_match_model1["corpus_id"] != best_match_model2["corpus_id"]:
        continue
    similarity_score1 = best_match_model1["score"]
    similarity_score2 = best_match_model2["score"]
    best_match_idx = best_match_model1["corpus_id"]
    best_match_row = df_max_views.iloc[best_match_idx]
    stakeholder = unique_stakeholders[idx]
    if similarity_score1 >= (1 - float(threshold)) and similarity_score2 >= (1 - float(threshold)):
        # Store the best match for the stakeholder
        for idx_orig_stakeholder, orig_stakeholder in enumerate(stakeholders):
            if orig_stakeholder == stakeholder:
                assert stakeholder_index_to_target_item_id[idx_orig_stakeholder] is None
                stakeholder_index_to_target_item_id[idx_orig_stakeholder] = (best_match_row["target_item_id"], best_match_row["target_page_id"])

    all_results[unique_stakeholders[idx]] = (
        best_match_row["normalized_anchor_text"],
        best_match_row["target_page_id"],
        best_match_row["target_item_id"],
        similarity_score1,
        similarity_score2,
    )

hit_count = sum([1 for item_id in stakeholder_index_to_target_item_id if item_id is not None])
print(
    f"Hit count: {hit_count} | Hit percentage before wiki: {hit_count / len(stakeholders) * 100:.2f}%"
)
unique_wiki_items = set([
    val for val in stakeholder_index_to_target_item_id if val is not None
])

if output_dir is not None:
    with open(output_dir / f"all_results_{event_name}.pkl", "wb") as f:
        pickle.dump(all_results, f)

# del all_results
# del search_results
# del unique_stakeholders
# del hit_count
# Out:
# Hit count: 9833 | Hit percentage before wiki: 68.58%

# %%
# Extend with wikidata info
all_wiki_info = []
wiki_info_index_to_itemid = []
wiki_info_index_to_page_id = []
itemid_to_wiki_info = {}
for val in tqdm(unique_wiki_items, desc="Fetching wiki info"):
    target_item_id, target_page_id = val
    wikidata_info = fetch_wikidata_info(target_item_id)
    if wikidata_info:
        itemid_to_wiki_info[target_item_id] = wikidata_info
        labels = wikidata_info["labels"]  # list of labels
        descriptions = (
            wikidata_info["main_label"].lower() + " " + wikidata_info["description"]
        )  # string
        aliases = wikidata_info["aliases"]  # list of aliases
        all_wiki_info += labels + [descriptions] + aliases
        wiki_info_index_to_itemid += [target_item_id] * (len(labels) + len(aliases) + 1)
        wiki_info_index_to_page_id += [target_page_id] * (len(labels) + len(aliases) + 1)
print(f"Length of wiki corpus: {len(all_wiki_info)}")
# del unique_wiki_items
# Out:
# Fetching wiki info: 100%|██████████| 1359/1359 [05:20<00:00,  4.24it/s]
# Length of wiki corpus: 26431

# %%
missing_stakeholders = list(set(
    [stakeholder for idx, stakeholder in enumerate(stakeholders) if stakeholder_index_to_target_item_id[idx] is None]
))
print(f"Length of missing stakeholders: {len(missing_stakeholders)}")
# Out:
# Length of missing stakeholders: 2095

# %%
missing_stakeholder_embeddings = (
    models[0].encode(
        missing_stakeholders,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    ),
    models[1].encode(
        missing_stakeholders,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    ),
)
all_wiki_info_embeddings = (
    models[0].encode(
        all_wiki_info,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    ),
    models[1].encode(
        all_wiki_info,
        show_progress_bar=True,
        convert_to_tensor=True,
        device=device,
        batch_size=batch_size,
    ),
)
# semantic search
search_results = (
    semantic_search(
        missing_stakeholder_embeddings[0],  # query embeddings
        all_wiki_info_embeddings[0],  # database embeddings (can remain on CPU)
        top_k=1,  # Retrieve the top match only, adjust as needed
        device=device,
    ),
    semantic_search(
        missing_stakeholder_embeddings[1],  # query embeddings
        all_wiki_info_embeddings[1],  # database embeddings (can remain on CPU)
        top_k=1,  # Retrieve the top match only, adjust as needed
        device=device,
    ),
)

del missing_stakeholder_embeddings
del all_wiki_info_embeddings
# Out:
# Encoding:   0%|          | 0/33 [00:00<?, ?it/s]
# Batches:   0%|          | 0/33 [00:00<?, ?it/s]
# Encoding:   0%|          | 0/413 [00:00<?, ?it/s]
# Batches:   0%|          | 0/413 [00:00<?, ?it/s]
# Query chunks: 100%|██████████| 21/21 [00:00<00:00, 479.19it/s]
# Query chunks: 100%|██████████| 21/21 [00:00<00:00, 520.98it/s]

# %%
missing_stakeholder_matches = {}
for idx in range(len(missing_stakeholders)):
    best_match_model1 = search_results[0][idx][0]
    best_match_model2 = search_results[1][idx][0]
    similarity_score1 = best_match_model1["score"]
    similarity_score2 = best_match_model2["score"]
    best_match_idx1 = best_match_model1["corpus_id"]
    best_match_idx2 = best_match_model2["corpus_id"]
    missing_stakeholder = missing_stakeholders[idx]
    item_id1 = wiki_info_index_to_itemid[best_match_idx1]
    item_id2 = wiki_info_index_to_itemid[best_match_idx2]
    missing_stakeholder_matches[stakeholder] = (
        similarity_score1,
        all_wiki_info[best_match_idx1],
        itemid_to_wiki_info[item_id1]["main_label"],
        similarity_score2,
        all_wiki_info[best_match_idx2],
        itemid_to_wiki_info[item_id2]["main_label"],
    )
    if item_id1 != item_id2:
        continue
    if similarity_score1 >= (1 - float(threshold)) and similarity_score2 >= (1 - float(threshold)):
        for stakeholder_index, stakeholder in enumerate(stakeholders):
            if stakeholder == missing_stakeholder:
                assert stakeholder_index_to_target_item_id[stakeholder_index] is None, f"Stakeholder {stakeholder} already has a match"
                stakeholder_index_to_target_item_id[stakeholder_index] = (item_id1, wiki_info_index_to_page_id[best_match_idx1])

if output_dir != None:
    with open(output_dir / f"stakeholders_{event_name}.pkl", "wb") as f:
        pickle.dump(stakeholders, f)
    with open(output_dir / f"stakeholder_index_to_target_item_id_{event_name}.pkl", "wb") as f:
        pickle.dump(stakeholder_index_to_target_item_id, f)
    with open(output_dir / f"missing_stakeholder_matches_{event_name}.pkl", "wb") as f:
        pickle.dump(missing_stakeholder_matches, f)


hit_count = sum([1 for item_id in stakeholder_index_to_target_item_id if item_id is not None])
print(
    f"Hit count: {hit_count} | Hit percentage after wiki: {hit_count / len(stakeholders) * 100:.2f}%"
)

del missing_stakeholders
del search_results
del missing_stakeholder_matches
# Out:
# Hit count: 10497 | Hit percentage after wiki: 73.22%

# %%
augmented_stakeholders = []
unique_stakeholders = list(set(stakeholders))
for stakeholder in tqdm(
    unique_stakeholders, total=len(unique_stakeholders), desc="Augmenting stakeholders"
):
    i = stakeholders.index(stakeholder)
    if stakeholder_index_to_target_item_id[i] is not None:
        stakeholder_itemid = stakeholder_index_to_target_item_id[i][0]
        wikidata_info = itemid_to_wiki_info[stakeholder_itemid]
        # Append label, description, and aliases to stakeholder name
        augmented_text = wikidata_info["main_label"]
        augmented_text += f" ({wikidata_info['description']})"
        if wikidata_info["en_aliases"]:
            augmented_text += (
                f" | Aliases: {', '.join(wikidata_info['en_aliases'])}"
            )
        augmented_stakeholders.append(augmented_text.lower())
    else:
        augmented_stakeholders.append(stakeholder.lower())  # If no match, keep original

if output_dir != None:
    with open(output_dir / f"stakeholder_to_wiki_info_{event_name}.pkl", "wb") as f:
        pickle.dump(itemid_to_wiki_info, f)

del all_wiki_info
# Out:
# Augmenting stakeholders: 100%|██████████| 3819/3819 [00:00<00:00, 7076.15it/s]

# %%
# clear cuda cache
if device == "cuda":
    torch.cuda.empty_cache()

stakeholder_embeddings = (
    (models[0].encode(
    augmented_stakeholders,
    device=device,
    show_progress_bar=True,
    convert_to_tensor=True,
    batch_size=batch_size,
    ).cpu()), 
    (models[1].encode(
    augmented_stakeholders,
    device=device,
    show_progress_bar=True,
    convert_to_tensor=True,
    batch_size=batch_size,
    ).cpu())
)

stakeholder_embeddings = (
    util.normalize_embeddings(stakeholder_embeddings[0]),
    util.normalize_embeddings(stakeholder_embeddings[1]),
)

stakeholder_cos_scores = (
    stakeholder_embeddings[0] @ stakeholder_embeddings[0].T,
    stakeholder_embeddings[1] @ stakeholder_embeddings[1].T,
)

del stakeholder_embeddings

stakeholder_cos_scores = (stakeholder_cos_scores[0] + stakeholder_cos_scores[1]) / 2
# Out:
# Encoding:   0%|          | 0/60 [00:00<?, ?it/s]
# Batches:   0%|          | 0/60 [00:00<?, ?it/s]

# %%
stakeholder_cos_scores.shape
# Out:
# torch.Size([3819, 3819])

# %%
print("Clustering stakeholders/targets threshold" f" {threshold}...")
# Use Agglomerative Clustering for stakeholders
if clustering_method == "agglomerative":
    stakeholder_replacement, clusters = agglomerative_clustering(
        unique_stakeholders, stakeholder_cos_scores, float(threshold)
    )
elif clustering_method == "fast":
    stakeholder_replacement, clusters = fast_clustering(
        stakeholder_cos_scores,
        unique_stakeholders,
        threshold=1 - float(threshold),
    )
else:
    raise ValueError("Invalid clustering method. Choose 'agglomerative' or 'fast'")

del stakeholder_cos_scores
# Out:
# Clustering stakeholders/targets threshold 0.15...
# Fast clustering start
# Finding clusters: 100%|██████████| 4/4 [00:00<00:00,  8.73it/s]
# Clustering done after 0.47 sec

# %%
stakeholder_index_to_target_item_id_copy = stakeholder_index_to_target_item_id.copy()

# %%
itemids_per_cluster = []
clusters_with_multiple_itemids = []
for stakeholder_ids in clusters:
    stakeholders_in_cluster = [unique_stakeholders[idx] for idx in stakeholder_ids]
    # check if any of the stakeholders in the cluster exist in stakeholder_index_to_target_item_id
    itemids_in_cluster = []
    for stakeholder_in_cluster in stakeholders_in_cluster:
        i = stakeholders.index(stakeholder_in_cluster)
        if stakeholder_index_to_target_item_id[i] is not None:
            itemids_in_cluster.append(stakeholder_index_to_target_item_id[i][0])
    itemids_per_cluster.append(set(itemids_in_cluster))
    # print(f"Cluster: {set(stakeholders_in_cluster)} | Itemids: {set(itemids_in_cluster)}")
    if len(set(itemids_in_cluster)) > 1:
        clusters_with_multiple_itemids.append(
            (set(stakeholders_in_cluster), set(itemids_in_cluster))
        )
    for stakeholder_in_cluster in stakeholders_in_cluster:
        i = stakeholders.index(stakeholder_in_cluster)
        if stakeholder_index_to_target_item_id[i] is not None:
            for orig_stakeholder_id, orig_stakeholder in enumerate(stakeholders):
                if orig_stakeholder in stakeholders_in_cluster:
                    if stakeholder_index_to_target_item_id[orig_stakeholder_id] is not None and stakeholder_index_to_target_item_id[i] != stakeholder_index_to_target_item_id[orig_stakeholder_id]:
                        # skip the replacement if the stakeholder is already replaced
                        print(f"Skipping replacement for {stakeholder_in_cluster}")
                        continue
                    stakeholder_index_to_target_item_id[orig_stakeholder_id] = stakeholder_index_to_target_item_id[i]
            break
# Out:
# Skipping replacement for central elections commission of russia
# Skipping replacement for central elections commission of russia
# Skipping replacement for central elections commission of russia
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for ukrainian air forces
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for russian civilians
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for wladimir klitschko
# Skipping replacement for asad majeed khan
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for international court of justice
# Skipping replacement for christian democratic union (cdu)

# %%
for i in range(len(stakeholder_index_to_target_item_id)):
    if stakeholder_index_to_target_item_id[i] is not None:
        wiki_info = itemid_to_wiki_info[stakeholder_index_to_target_item_id[i][0]]
        main_label = wiki_info["main_label"]
        orig_stakeholder = stakeholders[i]
        # copy the original stakeholder to the replacement
        old_replacement = stakeholder_replacement[orig_stakeholder]
        stakeholder_replacement[orig_stakeholder] = main_label

# %%
stakeholder_replacement_grouped = defaultdict(list)

for k,v in stakeholder_replacement.items():
    stakeholder_replacement_grouped[v].append(k)

# %%
stakeholder_eval_set_answers[7060:7090]
# Out:
# '"akhmat grozny", "akhmat"],]'

# %%
import json

# read the stakeholder_eval_set_answers.txt file
stakeholder_eval_set_answers = ""
with open("stakeholder_eval_set_answers.txt", "r") as f:
    for line in f:
        stakeholder_eval_set_answers += line.strip()

stakeholder_eval_set_answers = json.loads(stakeholder_eval_set_answers)
# Out:
# [['sergei karaganov'],
#  ['kajsa ollongren'],
#  ['mark n. katz'],
#  ['chuck schumer'],
#  ['president vladimir putin',
#   'vladimir putin',
#   'russian president vladimir putin'],
#  ['vitaliy vavryshchuk'],
#  ['the west'],
#  ['vladimir zelenskiy',
#   'volodimir zelenski',
#   'wolodimir zelenski',
#   'ukrainian president volodymyr zelensky',
#   'volodymyr zelenskiyy',
#   'vlodomyr zelensky',
#   'volodimir zelensky',
#   'volodymyr zelenskyj',
#   'volodymyr zelensky',
#   'wolodymyr selenskyj',
#   'vladimir aleksandrovich zelensky'],
#  ['ihor kolomoisky'],
#  ['jan lipavsky'],
#  ['oleksandr tarnawskyi',
#   'oleksandr tarnawskyj',
#   'oleksandr tarnavskiy',
#   'oleksandr tarnavskyi',
#   'oleksander tarnawskyi',
#   'oleksandr tarnawski',
#   'oleksander tarnavskyi',
#   'oleksandr tarnavsky',
#   'olexander tarnawskyj'],
#  ['dmitry ivanovich kuleba'],
#  ['oleksiy makeyev', 'oleksii makeiev'],
#  ['new people'],
#  ['united nations high commissioner for human rights',
#   'united nations human rights council'],
#  ['violeta artemchuk'],
#  ['anniken huitfeldt'],
#  ['dóra dúró'],
#  ['luisa gonzalez'],
#  ['natasha ivanova'],
#  ['uk foreign & commonwealth office'],
#  ['simone tagliapietra'],
#  ['peter brandt'],
#  ['general david petraeus'],
#  ['jack posobiec'],
#  ['department of homeland security'],
#  ['james hecker'],
#  ['western diplomats and officials in kiev'],
#  ['andrei kartapolov'],
#  ['federal tax service for the tyumen region'],
#  ['russian ministry of defense',
#   "russia's defence ministry",
#   "russia's ministry of defence",
#   'ministry of defense of russia',
#   'russian defense ministry',
#   'ministry of defence of the russian federation',
#   'ministry of defence of russia',
#   'ministry of defense of the russian federation',
#   'russian ministry of defence',
#   'russian defence ministry',
#   "russia's defense ministry",
#   'russian mod'],
#  ['g20 member states'],
#  ['konstantin mashovets'],
#  ['alexander kynew'],
#  ['michael thomas mccaul', 'michael mccaul'],
#  ['isamaa'],
#  ['ukrainian energy ministry'],
#  ['alena lunova'],
#  ['mariusz kaminski'],
#  ['critics'],
#  ['federal security service', 'fsb of russia'],
#  ['uk ministry of defence'],
#  ['ukrainian army',
#   "ukraine's armed forces",
#   'ukrainian troops',
#   'ukrainian defense forces',
#   'ukrainian forces',
#   'ukrainian defence forces',
#   "ukraine's defense forces",
#   'armed forces of ukraine',
#   'forces armées ukrainiennes',
#   'ukrainian armed forces',
#   'ukrainian military',
#   'defense forces of ukraine',
#   "ukraine's military",
#   'ukraine military'],
#  ['ukrainian ministry of defense'],
#  ['mcdonald lewanika'],
#  ['olga kazakova'],
#  ["general staff of ukraine's armed forces"],
#  ['kn pandita'],
#  ['yulia tymoshenko bloc'],
#  ['nigeria labour congress'],
#  ['claire coutinho'],
#  ['steve wright'],
#  ['herman haluschtschenko'],
#  ['polyakov leonid'],
#  ['jon sherman'],
#  ['james marks'],
#  ['philippe sands'],
#  ['garret graves'],
#  ['catherina colonna'],
#  ['alexander drozdenko'],
#  ['communist party usa'],
#  ['nataliia humeniuk'],
#  ['ukrainian military intelligence service'],
#  ['american public'],
#  ['ukrainian security service'],
#  ['kateryna ilikchiieva'],
#  ['wagner council of commanders'],
#  ["ukraine's foreign ministry"],
#  ['alexey likhachev'],
#  ['milan nic'],
#  ['anatoly khmeliovy'],
#  ['dmitry azarov'],
#  ['nataliia yemets'],
#  ['dimitri zhuravlev'],
#  ['roman osadchuk'],
#  ['emma odera'],
#  ['fiona hill'],
#  ['horst teltschik'],
#  ['russian media'],
#  ['russian lawmakers'],
#  ['united states department of defense'],
#  ['chrystia freeland'],
#  ['moscow times'],
#  ['stanislaw andrejtschuk'],
#  ['u.s. intelligence community'],
#  ['marcin walecki'],
#  ['ivan kyrylenko'],
#  ['mikhail murashko'],
#  ["people's council of the dpr"],
#  ['mikhailo podoliak'],
#  ['heinrich august winkler'],
#  ['epifanio'],
#  ['yurii shchyhol'],
#  ['jon finer'],
#  ['pacific gas & electric'],
#  ['margarita simonyan'],
#  ['organisation for security and cooperation in europe'],
#  ['denise nikolaevich miroshnichenko'],
#  ['foreign ministry of moldova', 'moldovan foreign ministry'],
#  ['mother and daughter'],
#  ['vasyl malyuk'],
#  ['naeem haider panjhuta'],
#  ['oleksandra romantsova'],
#  ['yulia gorbunova'],
#  ['nina antonova'],
#  ['iryna borovets'],
#  ['michael carpenter'],
#  ['boris grishin'],
#  ['netherlands'],
#  ['askad ashurbekov'],
#  ['irina'],
#  ['bangladesh nationalist party'],
#  ['david dunn'],
#  ['alexander bastrykin'],
#  ['ukrainian farmers'],
#  ['oleksandr rodyansky'],
#  ['carlos alzugaray'],
#  ['batu kutelia'],
#  ['elman nasirov'],
#  ['social democratic party (spd)', 'spd'],
#  ['frederica wilson'],
#  ['central electoral commission of the russian federation'],
#  ['eugene balitski'],
#  ['tatiana kastoueva-jean'],
#  ['bundeswehr'],
#  ['abbas galljamov'],
#  ['leonid zyuganov'],
#  ['pawel jablonski'],
#  ['bridget brink'],
#  ['mayor of kyiv'],
#  ['alexander titov'],
#  ['iran'],
#  ['centre of national resistance of the armed forces of ukraine',
#   'centre of national resistance of ukraine',
#   'center of national resistance of ukraine',
#   'ukrainian centre of national resistance',
#   'ukrainian center of national resistance',
#   'national resistance center of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces',
#   "national resistance center of the special operations forces of ukraine's armed forces",
#   'national resistance center of the special operations forces of the armed forces of ukraine',
#   "ukraine's national resistance center",
#   "ukraine's national resistance centre",
#   'ukrainian center for national resistance',
#   "centre national de la résistance d'ukraine",
#   'ukrainian national resistance center'],
#  ['grigorij meseznikov'],
#  ['ukrainian central election commission'],
#  ['serhiy tolstov'],
#  ['alexander aleksandrovich malkevich'],
#  ['ilya dmitriev'],
#  ['russian ministry of finance', 'finance ministry of russia'],
#  ['volodymyr fito'],
#  ['north korea'],
#  ['ma ying-jeou'],
#  ['freddy versluys'],
#  ['rudy giuliani'],
#  ['oleg artamonov'],
#  ['oleg bondarenko'],
#  ['viacheslav bondarenko'],
#  ['serhii borzov', 'serhiy borsov'],
#  ['roman starovoyt', 'roman starovoit'],
#  ['yuriy ignat'],
#  ['sergey kiriyenko', 'sergei kiriyenko'],
#  ['vitalii kim', 'vitaly kim'],
#  ["ukraine's defense forces"],
#  ['dmitry smith'],
#  ['vitalii neveselyi'],
#  ['ilya berezkin'],
#  ['alan winde'],
#  ['ukrainian official'],
#  ['bob hamilton'],
#  ['institute for war studies'],
#  ['enrique refoyo'],
#  ['maxim kozitsky'],
#  ['ishikane kimihiro'],
#  ['paul bacot'],
#  ['lloyd j. austin iii'],
#  ['mikhail mikhaylovich kotyukov'],
#  ['iryna gerashchenko'],
#  ['singapore'],
#  ['kyiv and its allies'],
#  ['dario abdula camal'],
#  ['onufrio'],
#  ['ella pamfilova'],
#  ['yves plasseraud'],
#  ['ashok gulati riya das'],
#  ['polina'],
#  ['dario fabbri'],
#  ['oleksandr turchynov'],
#  ['olena zelensky'],
#  ['g7 group'],
#  ['vladimir medinsky'],
#  ['mohamed bazoum'],
#  ['ukrainian lawmakers'],
#  ['guerrillas'],
#  ['oleh soskin'],
#  ['alternance 2023 alliance'],
#  ['anthony rota'],
#  ['ukrainian partisans'],
#  ['klaus iohannis'],
#  ['erika veit'],
#  ['alexander lezhava'],
#  ['russian-installed officials',
#   'russia-installed officials',
#   'russian-installed authorities',
#   'russian-appointed officials',
#   'kremlin-installed officials'],
#  ['abbas gallyamov',
#   'abbas galyamov',
#   'abbas galljamov',
#   'abbas galiamov',
#   'abbas galiyamov'],
#  ['luiz inácio lula da silva',
#   'brazilian president luiz inacio lula da silva',
#   'luis inacio lula da silva',
#   'lula da silva',
#   'luiz inacio lula da silva'],
#  ['united kingdom',
#   'britain',
#   'british government',
#   'great britain',
#   'uk government'],
#  ['iryna lutsenko'],
#  ['yurii lutsenko'],
#  ['kremlin', 'the kremlin'],
#  ['france', 'french government'],
#  ['tatyana dmitrieva', 'dmitrieva tatyana'],
#  ['miroslav jenča', 'miroslav jenca'],
#  ['alexei shevtsov'],
#  ['dmitry shevtsov'],
#  ['akhmat grozny', 'akhmat']]

# %%
# Positive samples (pairs of items within the same list)
positive_samples = []
for sublist in stakeholder_eval_set_answers:
    for i in range(len(sublist)):
        for j in range(i + 1, len(sublist)):
            positive_samples.append((sublist[i], sublist[j]))

# Negative samples (pairs of items from different sublists)
negative_samples = []
for i in range(len(stakeholder_eval_set_answers)):
    for j in range(i + 1, len(stakeholder_eval_set_answers)):
        # Create all possible pairs between sublist[i] and sublist[j]
        for element1 in stakeholder_eval_set_answers[i]:
            for element2 in stakeholder_eval_set_answers[j]:
                negative_samples.append((element1, element2))

print(f"Number of positive samples: {len(positive_samples)}")
print(f"Number of negative samples: {len(negative_samples)}")
# Out:
# Number of positive samples: 398
# Number of negative samples: 42088

# %%
negative_samples[:10]
# Out:
# [('sergei karaganov', 'kajsa ollongren'),
#  ('sergei karaganov', 'mark n. katz'),
#  ('sergei karaganov', 'chuck schumer'),
#  ('sergei karaganov', 'president vladimir putin'),
#  ('sergei karaganov', 'vladimir putin'),
#  ('sergei karaganov', 'russian president vladimir putin'),
#  ('sergei karaganov', 'vitaliy vavryshchuk'),
#  ('sergei karaganov', 'the west'),
#  ('sergei karaganov', 'vladimir zelenskiy'),
#  ('sergei karaganov', 'volodimir zelenski')]

# %%
stakeholder_clusters_final = [
    [stakeholder for stakeholder in cluster] for cluster in stakeholder_replacement_grouped.values()
]

stakeholder_clusters_final
# Out:
# [['central elections commission of russia',
#   "russia's elections commission",
#   'russian central election commission',
#   'the central election commission of russia',
#   'central election commission of the russian federation',
#   'central electoral commission of the russian federation',
#   'central election commission of russia',
#   'moscow regional election committee',
#   'russian election commission',
#   "russia's central election commission",
#   "russia's election commission",
#   'russian central electoral commission',
#   "russia's central elections commission",
#   'russian electoral commission',
#   'russian election authorities',
#   'central electoral commission of russia',
#   'election commission of tsentralny of the russian federation',
#   "moscow's electoral commission",
#   "moscow's election commission",
#   'moscow city election commission'],
#  ['ukrainian central election commission',
#   "ukraine's central election commission",
#   'central election commission of ukraine'],
#  ['volodymyr zelenskyy',
#   'wolodimir selenski',
#   'volodymyr zelenskyj',
#   'volodimir zelenski',
#   'volodymyr zelenskiyy',
#   'volodymir zelensky',
#   'volodymyr zelenski',
#   'vlodomyr zelensky',
#   'wolodymyr selenskyj',
#   'vladimir zelensky',
#   'wolodimir selenskij',
#   'volodomyr zelenskiy',
#   'volodymyr zelenskiy',
#   'vladimir zelenskyy',
#   'vladimir aleksandrovich zelensky',
#   'president volodymyr zelensky',
#   'zelenskyy',
#   'volodymyr zelensky',
#   'volodymyr zelenskyi',
#   'volodimir zelensky',
#   'wolodymyr zelenskyj',
#   'vladimir zelenskiy',
#   'ukrainian president volodymyr zelensky'],
#  ['ukrainian resistance center',
#   'ukrainian national resistance center',
#   'ukrainian center for national resistance',
#   'national resistance center of ukraine',
#   'ukrainian center of national resistance',
#   "ukraine's national resistance center",
#   'ukrainian centre of national resistance',
#   "ukraine's national resistance centre",
#   'center of national resistance of ukraine',
#   'centre of national resistance of ukraine',
#   'centre of national resistance of the armed forces of ukraine',
#   'ukrainian resistance',
#   "centre national de la résistance d'ukraine",
#   'national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian center for national opposition',
#   'national resistance center of the special operations forces of the armed forces of ukraine',
#   'pro-ukrainian resistance group',
#   "national resistance center of the special operations forces of ukraine's armed forces"],
#  ['u.k. defense ministry',
#   'ministry of defence of the united kingdom',
#   'uk ministry of defence',
#   'uk defense ministry',
#   "britain's defense ministry",
#   'british ministry of defence',
#   "britain's defence ministry",
#   "united kingdom's ministry of defence",
#   'ministry of defence',
#   'united kingdom ministry of defence',
#   "united kingdom's ministry of defense",
#   'british ministry of defense',
#   'ministry of defense of the united kingdom',
#   'uk ministry of defense',
#   'uk defence ministry',
#   "uk's ministry of defence",
#   'british defense ministry'],
#  ['ukrainian defence forces',
#   'ukrainian forces',
#   "ukraine's armed forces",
#   "ukraine's defense forces",
#   'forces armées ukrainiennes',
#   'ukrainian defense forces',
#   'ukrainian military',
#   'ukrainian troops',
#   'defense forces of ukraine',
#   'armed forces of ukraine',
#   "ukraine's military",
#   'ukrainian armed forces',
#   'ukraine military',
#   'ukrainian military officials',
#   'ukrainian army'],
#  ['ministry of defence of the russian federation',
#   'russian ministry of defense',
#   "russia's ministry of defence",
#   'russian ministry of defence',
#   'russian mod',
#   'ministry of defence of russia',
#   'ministry of defense of russia',
#   'russian defense ministry',
#   'ministry of defense of the russian federation',
#   "russia's defence ministry",
#   "russia's defense ministry",
#   'russian defence ministry'],
#  ['ministry of foreign affairs of ukraine',
#   "ukraine's ministry of foreign affairs",
#   "ukraine's foreign affairs ministry",
#   'ukrainian foreign ministry',
#   'ukrainian foreign minister',
#   "ukraine's foreign ministry",
#   'ministère ukrainien des affaires étrangères',
#   'ukrainian ministry of foreign affairs',
#   'ukraine foreign ministry',
#   'ukrainian ministry',
#   'ukrainian foreign affairs ministry'],
#  ['mykhailo podoliak',
#   'mykhailo podolyak',
#   'mykhalio podlyak',
#   'mykhaylo podolyak',
#   'mikhailo podoliak',
#   'mikhaïlo podoliak',
#   'mikhail podoliak',
#   'mykola podolsky',
#   'mikhailo podolyak',
#   'mijailo podoliak',
#   'miikhail podoliak'],
#  ['state major of the armed forces of ukraine',
#   "general staff of ukraine's armed forces",
#   'general staff of the ukrainian armed forces',
#   'general staff of the armed forces of ukraine',
#   'ukrainian armed forces general staff',
#   'general staff of ukraine',
#   'ukrainian general staff',
#   "ukraine's general staff",
#   'general staff of the ukrainian army',
#   'staff general of ukraine'],
#  ['verkhovna rada',
#   'verhovna rada',
#   'ukraine parliament',
#   'parliament of ukraine',
#   'kiev parliament',
#   "ukraine's verkhovna rada",
#   'ukrainian parliament',
#   "ukraine's parliament",
#   'verkhovna rada of ukraine'],
#  ['ukrainian security service',
#   'security service of ukraine (sbu)',
#   'security service of ukraine',
#   'ukrainian security service (sbu)',
#   'ukrainian security services',
#   'ukrainian secret service',
#   "ukraine's sbu security service",
#   "ukraine's security service",
#   'ukrainian sbu security service'],
#  ['kyiv and its western allies',
#   'kyiv and its allies',
#   "kyiv's allies",
#   'allies of kyiv',
#   'kiev and its western allies',
#   'kiev and its allies',
#   'western allies of ukraine',
#   'kiev and its western supporters',
#   'ukraine and its allies'],
#  ['moscow',
#   'russia',
#   'russian federation',
#   'russian empire',
#   'russian government',
#   'russia government',
#   'the russian federation',
#   'russian state'],
#  ['oleksandr tarnavskiy',
#   'oleksandr tarnavskyi',
#   'oleksandr tarnawskyi',
#   'oleksandr tarnawskyj',
#   'oleksandr tarnawski',
#   'olexander tarnawskyj',
#   'oleksander tarnawskyi',
#   'gen. oleksandr tarnavskiy'],
#  ['russian-installed authorities',
#   'russian-installed officials',
#   'russian-backed authorities',
#   'russia-installed officials',
#   'russian-installed administration',
#   'russian-appointed officials',
#   'pro-russian authorities',
#   'russian occupying authorities'],
#  ['main intelligence directorate of ukraine',
#   "ukraine's intelligence service",
#   "ukraine's intelligence ministry",
#   'ukrainian military intelligence service',
#   "ukraine's domestic intelligence agency",
#   'ukrainian intelligence services',
#   'ukrainian military intelligence',
#   'ukrainian defense intelligence directorate (gur)'],
#  ['nikolay bulayev',
#   'nicolai boulaev',
#   'nikolai bulayev',
#   'nikolai bulaev',
#   'nikolai ivanovich bulayev',
#   'nikolai bolayev',
#   'nicholas ivanovich bulaev'],
#  ['lukashenka',
#   'alaksandr łukašenka',
#   'alexandr lukashenko',
#   'belarusian president alexander lukashenko',
#   'alexander lukashenko',
#   'aleksandr lukashenko',
#   'aleskandr lukashenko'],
#  ['iryna matsevko',
#   'irina vereshchuk',
#   'iryna vereshchuk',
#   'irina scherbakowa',
#   'iryna yurchenko',
#   'iryna vereschuk',
#   'iryna gerashchenko'],
#  ['american institute for the study of war',
#   'institute of study of war',
#   'institute of war studies',
#   'institute for the study of war',
#   'institute for war studies',
#   'institute study of war',
#   'us institute for the study of war'],
#  ['romanian defence ministry',
#   'ministry of defense of romania',
#   "romania's defence ministry",
#   'romanian ministry of national defense',
#   'ministry of defence of romania',
#   "romania's national defense ministry",
#   'romanian defense ministry'],
#  ['ukrainian military official',
#   'ukrainian officer',
#   'ukrainian official',
#   'ukrainian military commanders',
#   'unnamed ukrainian official',
#   'ukraine soldier',
#   'ukrainian-born russian military officer'],
#  ['foreign, commonwealth and development office',
#   'ministry of foreign affairs of the united kingdom',
#   'uk foreign office',
#   'foreign office',
#   'uk foreign & commonwealth office',
#   'british foreign office'],
#  ['us government',
#   'united states of america',
#   'the united states',
#   'united states',
#   'united states government',
#   'washington'],
#  ['european union',
#   'western powers',
#   'union européenne',
#   'europe',
#   'european governments',
#   'eu'],
#  ['russian forces',
#   'russian officials',
#   'russian army',
#   'russian troops',
#   'russian authorities',
#   'russian local officials'],
#  ['oleksandr prokoudin',
#   'oleksandr prokudin',
#   'oleksandr prokoedin',
#   'oleksandre prokoudine',
#   'olexander prokudin',
#   'oleksandr brokodin'],
#  ['anthony j. blinken',
#   'u.s. secretary of state antony blinken',
#   'antony blinken',
#   'anthony john blinken',
#   'united states secretary of state antony blinken',
#   'anthony blinken'],
#  ['ukrainian defense ministry',
#   "ukraine's defense ministry",
#   'ukrainian defense minister',
#   'ukrainian ministry of defence',
#   'ukrainian ministry of defense',
#   "ukraine's defence ministry"],
#  ['a just russia party - patriots - for the truth',
#   'a just russia party - patriots for the truth',
#   'fair russia – for truth party',
#   'a just russia party - for the truth',
#   'a just russia party',
#   'a just russia'],
#  ['russian embassy in the us',
#   'russian embassy in the united states',
#   'russian embassy in the u.s.',
#   'embassy of the russian federation in the united states',
#   'embassy of russia in the united states'],
#  ['anton shekhovtsov',
#   'oleksiy shekhovtsov',
#   'anton chekhovtsov',
#   'oleksandr shekhovtsov',
#   'alexei shevtsov'],
#  ['us department of defense',
#   'united states department of defense',
#   'pentagon',
#   'pentagon officials',
#   'department of defense'],
#  ['us state department',
#   'u.s. state department',
#   'united states department of state',
#   'department of state of the united states',
#   'u.s. department of state'],
#  ["ukrainian defense ministry's main intelligence directorate",
#   'general directorate of defense intelligence of ukraine',
#   'ukrainian main military intelligence directorate',
#   "general directorate of intelligence of ukraine's ministry of defense",
#   'ukrainian defense intelligence directorate'],
#  ['serghei lavrov',
#   'sergei lavrov',
#   'sergey lavrov',
#   'sergej lawrow',
#   'sergej lavrov'],
#  ['group of seven',
#   'g7 group',
#   'group of 7',
#   'g7 group of major industrialised countries',
#   'g7'],
#  ['valerii zaluzhnyy',
#   'valeriy zaluzhnyi',
#   'valerii zaluzhnyi',
#   'gen valerii zaluzhnyi',
#   'valery zaloujny'],
#  ['president vladimir putin',
#   'vladimir putin',
#   'wladimir putin',
#   'putin',
#   'russian president vladimir putin'],
#  ['serhiy aksionov',
#   'sergei aksionov',
#   'sergei aksyonov',
#   'alexei aksyonov',
#   'sergey aksyonov'],
#  ['sergey kravtsov',
#   'sergei kravtsov',
#   'sergei kravtov',
#   'dmitry krylov',
#   'dmitry shevtsov'],
#  ['luiz inácio lula da silva',
#   'luiz inacio lula da silva',
#   'luis inacio lula da silva',
#   'lula da silva',
#   'brazilian president luiz inacio lula da silva'],
#  ['andriy kryvtsov',
#   'andriy kovalyov',
#   'andriy yusov',
#   'andriy kovalev',
#   'andrii kovalov'],
#  ['dmitro kuleba',
#   'dmitro koeleba',
#   'dmytro kuleba',
#   'dimitro kuleba',
#   'dymtro kuleba'],
#  ['russian milblogger',
#   'russian milbloggers',
#   'russian mil-bloggers',
#   'russian military blogger',
#   'russian military bloggers'],
#  ['eugene balitsky',
#   'eugene balitski',
#   'evgeniy balitsky',
#   'yevgeniy balitsky',
#   'yevgeny balitsky'],
#  ['hanna malijar',
#   'hanna maliar',
#   'hanna maljar',
#   'hannah maliar',
#   'hanna malyar'],
#  ['russian and occupation authorities',
#   'russian occupation officials',
#   'russian occupation administration',
#   'russian occupation administrations'],
#  ['unnamed russian official',
#   'an unnamed russian official',
#   'russian official',
#   'russian government official'],
#  ['ukrainian air forces'],
#  ["ukraine's air force", 'ukrainian air force', 'ukraine air force'],
#  ['government of ukraine',
#   'ukrainian government member',
#   'ukrainian officials',
#   'cabinet of ministers of ukraine'],
#  ['recep tayyip erdogan',
#   'recep tayyip erdoğan',
#   'recep erdogan',
#   'tayyip erdogan'],
#  ['russian interior ministry',
#   'russian ministry of interior',
#   'russian ministry of internal affairs',
#   'interior ministry of russia'],
#  ['vassily a. nebenzia',
#   'vasily nebenzia',
#   'vassily nebenzia',
#   'vasily nebenzya'],
#  ['german ministry of foreign affairs',
#   'foreign office of germany',
#   'ministry of foreign affairs of germany',
#   'german foreign office'],
#  ['ukrainian authorities',
#   'ukraine government',
#   'ukraine',
#   'ukrainian government'],
#  ['yuriy sobolevsky',
#   'yuriy sobolevskyi',
#   'yurii sobolevskyi',
#   'yurii sobolevskii'],
#  ['azerbaijani ministry of foreign affairs',
#   'ministry of foreign affairs of azerbaijan',
#   'azerbaijani foreign ministry',
#   "azerbaijan's foreign ministry"],
#  ['great britain', 'british government', 'united kingdom', 'britain'],
#  ['oleksiy danilov', 'oleksii danylov', 'aleksey danilov', 'oleksi danilov'],
#  ['fsb of russia',
#   'federal security service',
#   'federal security service of the russian federation',
#   'russian federal security service'],
#  ['ivan ichtchenko',
#   'viktor tkachenko',
#   'viktor yushchenko',
#   'alexander yushchenko'],
#  ['andrei aleksyenko',
#   'andreï alekseïenko',
#   'sergei aleynik',
#   'aleksey arestovich'],
#  ['nicol pashinyan',
#   'armenian prime minister nikol pashinyan',
#   'nikol pashinyan',
#   'nikol pashinian'],
#  ['yabloko party',
#   'jabloko',
#   'yabloko',
#   'liberal russian united democratic party yabloko'],
#  ['andriy sadovyi', 'andri sadovi', 'andriy sadovy', 'andriy sadoviy'],
#  ['dmitri medwedew', 'dmitri medvedev', 'dmitry medvedev', 'dimitri medvedev'],
#  ['sergei shoigu', 'sergey shoygu', 'serghei shoigu', 'sergey shoigu'],
#  ['serhii cherevaty',
#   'serhii cherevatyi',
#   'serhiy cherevatyi',
#   'serhiy cherevaty'],
#  ['tass news agency', 'tass', 'itar-tass', 'russian state press agency tass'],
#  ['andrei turchak', 'andrey turchak', 'andrej turtschak', 'andreï tourtchak'],
#  ['andrei fedorov', 'fedorov', 'valery fedorov', 'mikhail fyodorov'],
#  ['alexei venediktov',
#   'alexey venediktov',
#   'aleksej venediktov',
#   'aleksei a. venediktov'],
#  ['russian foreign ministry',
#   "russia's foreign ministry",
#   'russian ministry of foreign affairs',
#   'ministry of foreign affairs of russia'],
#  ['stanislav andreichuk',
#   'stanislaw andrejtschuk',
#   'stanislav andrejchuk',
#   'stanislav andreychuk'],
#  ['ilia yevlash', 'illia yevlash', 'ilia yevlach', 'ilya yevlash'],
#  ['oleg zakharov',
#   'alexander zheltyakov',
#   'igor zakharov',
#   'alexander zakharchenko'],
#  ['mark a. milley',
#   'mark milley',
#   'general mark milley',
#   'gen. mark a. milley'],
#  ['denis puschilin', 'denis pushilin', 'denis puchilin', 'denis pushlin'],
#  ['vasily malyuk', 'vasyl malyuk', 'vasyl malyk', 'vasyl maliuk'],
#  ['u.s. government',
#   'us officials',
#   'united states officials',
#   'government of the united states'],
#  ['abbas galljamov', 'abbas galljamow', 'abbas galiyamov', 'abbas galyamov'],
#  ['kateryna tereshchenko',
#   'kateryna pavlichenko',
#   'kateryna ilikchiieva',
#   'kateryna rashevska'],
#  ['kyrylo budanov', 'kryrylo budanov', 'kyrlo budanov', 'kirilo budanov'],
#  ['organisation for security and cooperation in europe',
#   'osce',
#   'organization for security and co-operation in europe',
#   'organization for security and cooperation in europe'],
#  ['igor klymenko', 'igor klimenko', 'andrei klychkov', 'ihor klymenko'],
#  ['russian civilians', 'russian soldiers'],
#  ['russian armed forces', 'russian military'],
#  ['yulia svyrydenko',
#   'yuliia svyridenko',
#   'julia svyrydenko',
#   'yuliya yurchenko'],
#  ['cabinet of ministers of the russian federation',
#   'government of the russian federation',
#   'russian cabinet of ministers',
#   'government of russia'],
#  ['chinese government', 'beijing', 'china', "people's republic of china"],
#  ['marianna sumskaya',
#   'sumskaya marianna',
#   'marianna skorniakova',
#   'maria sukalskaya'],
#  ['grigori melkonyantsia',
#   'grigori melkoniants',
#   'grigory melkonyants',
#   'grigori melkonjanz'],
#  ['mikhail podolyak', 'yuriy podolyaka', 'yuri podolyaka'],
#  ['yuriy pohulyajko', 'yuriy pohuljaiko', 'yuriy konovalenko'],
#  ['ilya dmitriev', 'ilya matveev', 'leonid dmitriev'],
#  ["electoral commission of luhansk people's republic",
#   "central electoral commission of luhansk people's republic",
#   "election commission of luhansk people's republic"],
#  ['luisa gonzález', 'luisa gonzalez', 'luisa gonzales'],
#  ['local residents of kherson region',
#   'citizens of kherson region',
#   'residents of kherson'],
#  ['russian election commissions',
#   'russian-formed election commissions',
#   'russian electoral officials'],
#  ['western nations', 'western governments', 'western states'],
#  ['romanian ministry of foreign affairs',
#   'ministry of foreign affairs of romania',
#   'romanian foreign ministry'],
#  ['mikhail vinogradov', 'mikhaïl vinogradov', 'vinogradov mikhail'],
#  ['dmitri peskow', 'dmitri peskov', 'dmitry peskov'],
#  ['andrij kostin', 'andrii kostin', 'andriy kostin'],
#  ['alexey navalny', 'aleksei navalny', 'alexei navalny'],
#  ['united nations secretary-general antonio guterres',
#   'antonio guterres',
#   'antónio guterres'],
#  ['ihor kolomoyskyi', 'ihor kolomoisky', 'igor kolomoysky'],
#  ['andrey kurshin', 'andrey kurkov', 'andrei kurshin'],
#  ['natalia budarina', 'natalya budarina', 'natalia boudarina'],
#  ['kateryna', 'bondarenko tatyana', 'kateryna stepanenko'],
#  ['mikhail razvozhaev', 'mikhail razvozhayev', 'mikhail razvoshayev'],
#  ['united russia', 'united russia party', 'geeintes russland'],
#  ['denys shmygal', 'denys shmyhal', 'denys chmygal'],
#  ["electoral commission of donetsk people's republic",
#   "central electoral commission of donetsk people's republic",
#   "central election commission of the donetsk people's republic"],
#  ['valeri garbouzov', 'valery garbuzov', 'vladimir garbuzov'],
#  ['oleksandre syrsky', 'oleksandr syrsky', 'oleksandr syrskyi'],
#  ['wladimir klitschko'],
#  ['vitali klitschko', 'vitaliy klitschko'],
#  ['kim jong-un', 'kim yong ho', 'kim jong un'],
#  ['sergey karaganov', 'sergei karaganov', 'sergueï karaganov'],
#  ['us intelligence community',
#   'u.s. intelligence community',
#   'u.s. intelligence agencies'],
#  ['andrei klimov', 'andrey klychkov', 'andrey klimov'],
#  ['dmitry zhuravlev', 'dimitri zhuravlev', 'alexey zhuravlev'],
#  ['michal šimečka', 'michal simečka', 'michal simecka'],
#  ['andrei viktorovich gurulev', 'andrei gurulev', 'andrey gurulev'],
#  ['josep borrell', 'josep borell', 'josep borrell fontelles'],
#  ['róbert fico',
#   'robert fico',
#   "slovakia's former prime minister robert fico"],
#  ['oleksandr turchynov', 'oleksander tarnavskyi', 'oleksandr tarnavsky'],
#  ['igor girkin', 'igor guirkin', 'igor strelkov'],
#  ['officials in kiev',
#   'government in kiev',
#   'western diplomats and officials in kiev'],
#  ['sviatoslav shevchuk',
#   'svyatoslav shevchuk',
#   'major archbishop svetoslav shevchuk'],
#  ['investigative committee of the russian federation',
#   'investigating committee of the russian federation',
#   'russian investigative committee'],
#  ["self-proclaimed donetsk people's republic",
#   "citizens of donetsk people's republic",
#   "donetsk people's republic"],
#  ["citizens of luhansk people's republic",
#   "lugansk people's republic",
#   "luhansk people's republic"],
#  ['mi6', 'british intelligence', 'uk intelligence'],
#  ['piotr müller', 'piotr muller', 'piotr mueller'],
#  ['alexander kofman', 'aleksandr kofman', 'michael kofman'],
#  ['ivailo ivanov', 'vitaly nikolaevich ivanov', 'oleg ivanov'],
#  ['ella pamfilowa', 'ella pamfilova', 'ella panfilova'],
#  ['residents of zaporykia',
#   'citizens of zaporizhia oblast',
#   'people in zaporizhzhia oblast'],
#  ['exiled mayor of mariupol',
#   'mayor of mariupol',
#   'exiled ukrainian mayor of mariupol'],
#  ['alternative for germany', 'alternative for germany (afd)', 'afd'],
#  ['vitaliy vavryshchuk', 'vitaly vavryshchuk', 'vitaliy prashchouk'],
#  ['g7 foreign ministers',
#   'foreign ministers of the g7 and european union',
#   'g9 foreign ministers'],
#  ['tatiana', 'tatiana stanovaya', 'tatiana stanovaja'],
#  ['natalia humenyuk', 'nataliya gumenyuk', 'nataliya humenyuk'],
#  ['gennady kuznin', 'gennadiy kuzmin', 'gennadi kuzmyn'],
#  ['olga aivazovska', 'olga gnezdilova', 'olga zemtsova'],
#  ['cuban foreign ministry',
#   'ministry of foreign affairs of cuba',
#   'cuban ministry of foreign affairs',
#   'czech ministry of foreign affairs',
#   'czech foreign ministry'],
#  ['mykola urzhalovych', 'mykola urschalowytsch', 'mykola ursjalovytj'],
#  ['alexander aleksandrovich malkevich',
#   'alexander malkevich',
#   'sergei aleksandrovich malinkovich'],
#  ['republican party in the usa', 'republicans', 'republican party'],
#  ['wagner private military company', 'wagner pmc', 'wagner group'],
#  ['oleksandr demchenko', 'andriy demchenko', 'andrii senchenko'],
#  ['vadym skibitsky', 'vadym skibitskyi', 'vadym skibitskiy'],
#  ['vadimir saldo', 'vladimir saldo', 'volodymyr saldo'],
#  ['turkey', 'türkiye', 'turkish government'],
#  ['serhiy lysak', 'sergiy lysak', 'serhii lysak'],
#  ['andriy ryzhenko', 'serhiy ryzhenko', 'andriy lysenko'],
#  ['regional election commission',
#   'central election commission',
#   'central elections commission'],
#  ['french ministry of foreign affairs',
#   'ministry of foreign affairs of france',
#   'french foreign ministry'],
#  ['anotoly antonov', 'anatoly antonov', 'anatoly ivanovich antonov'],
#  ['ukrainian special forces',
#   "ukraine's special operation forces",
#   'ukrainian special operations forces'],
#  ['valery zaluzhny', 'valery zalouzhny', 'valery fedorovich zaluzhny'],
#  ['sergey sobyanin', 'sergej sobyanin', 'sergei sobyanin'],
#  ['maria zajárova', 'marina zakharova', 'maria zakharova'],
#  ['rustem umerov', 'rustem umerow', 'rustem umierov'],
#  ['yuriy ihnat', 'yurii ihnat', 'yuriy ignat'],
#  ['olga kravchenko', 'olga shevchenko', 'olga kazakova'],
#  ['herman galushchenko', 'herman galuschenko', 'german galushchenko'],
#  ['oleksiy chernyshov', 'boris chernyshov', 'oleksandr korniyenko'],
#  ['mykola solsky', 'mykola solskyi'],
#  ['dmitry ivanovich kuleba', 'oleksiy kuleba'],
#  ['ihor kolykhaev', 'ihor khlivetsky'],
#  ['iryna dowhan', 'iryna dovhan'],
#  ['svyatoslav kolykhaev', 'igor kolykhaev'],
#  ['akhmat grozny', 'akhmat'],
#  ['svetlana gannushkina', 'svetlana ganushkina'],
#  ["ukraine's permanent representative to the un", "ukraine's un envoy"],
#  ['nikolai denkov', 'nikolay denkov'],
#  ['sergei mikhaylovich sokol', 'sergei sokol'],
#  ['barry r. posen', 'barry posen'],
#  ['jurii sheliazhenko', 'yurii sheliazhenko'],
#  ['dmitry muratov', 'dmitri muratov'],
#  ['national resistance centre', 'national resistance center'],
#  ['serhiy popko', 'sergiy popko'],
#  ['vitaly barabash', 'vitaliy barabash'],
#  ['lindsey o. graham', 'lindsey graham'],
#  ['anders aslund', 'anders åslund'],
#  ['abbas galiamov', 'abbas gallyamov'],
#  ['robert menendez', 'bob menendez'],
#  ['andrei kartapolov', 'andrey kartapolov'],
#  ['alexander gusev', 'dmitry gusev'],
#  ['marcin przydach', 'marcin przydacz'],
#  ['government of venezuela', "venezuela's government"],
#  ['pedro sánchez', 'pedro sanchez'],
#  ['ukrainian people', 'ukrainian civilian population'],
#  ['alexander iii', 'alexander'],
#  ['volodymyr vasylenko', 'volodymyr fesenko'],
#  ['alena bulgakova', 'alyona bulgakova'],
#  ['oleksandr kraiev', 'oleksandr kubrakov'],
#  ['petro andryushchenko', 'petr andryushchenko'],
#  ['sergei zbinsky', 'sergey zybinsky'],
#  ['benjamin netanyahu', 'binyamin netanyahu'],
#  ['michael mccaul', 'michael thomas mccaul'],
#  ['imran ahmad khan niazi', 'imran khan'],
#  ['françois hollande', 'francois hollande'],
#  ['yurii lutsenko', 'iryna lutsenko'],
#  ['oleksander shtupun', 'oleksandr shtupun'],
#  ['vitalii kim', 'vitaly kim'],
#  ['ihor romanenko', 'igor romanenko'],
#  ['lloyd j. austin iii', 'lloyd austin'],
#  ['saudi arabia', 'government of saudi arabia'],
#  ['ukrainian partisans', "ukraine's partisans"],
#  ['natasha ivanova', 'ivanova irina'],
#  ['andrii sibyga', 'andrii sybiga'],
#  ['yuriy afanasievsky', 'yuri afanasyevsky'],
#  ['danish government', 'denmark'],
#  ['olga', 'olga kirillova'],
#  ['pavlo kyrylenko', 'ivan kyrylenko'],
#  ['law and justice party', 'law and justice'],
#  ['us secretary of state', 'united states secretary of state'],
#  ['european commission', 'commission européenne'],
#  ['janet yellen', 'janet l. yellen'],
#  ['alexey polishchuk', 'oleksandr polishchuk'],
#  ['nadiya didenko', 'iryna didenko'],
#  ['pro-russian authorities in occupied ukraine',
#   'pro-russian authorities in occupied regions'],
#  ['foreign experts', 'international experts'],
#  ['konstantin nikolaevich kostin', 'konstantin kostin'],
#  ['kyiv', 'kiev'],
#  ['mariusz kamiński', 'mariusz kaminski'],
#  ['aldeas infantiles sos', 'sos kinderdörfer'],
#  ['miroslav jenca', 'miroslav jenča'],
#  ['pakistani government', 'pakistan government'],
#  ['rogov vladimir', 'yaroslav halas'],
#  ['mikhail fedorov', 'andrey viktorovich fedorov'],
#  ['nato allies', 'nato'],
#  ['serhiy nayev', 'serhii nayev'],
#  ['vera jourova', 'věra jourová'],
#  ['russian state duma',
#   'state duma of the federal assembly of the russian federation'],
#  ["ukraine's general prosecutor's office",
#   'office of the prosecutor general of ukraine'],
#  ['andrew jagaye karnely', 'andrew jagaye karnley'],
#  ['kemal kılıçdaroğlu', 'kemal kilicdaroglu'],
#  ['valentina čupik', 'valentina chupik'],
#  ['vladimir schkunow', 'vladimir shkunov'],
#  ['norway', 'norwegian government'],
#  ['sergei ryabkov', 'sergey ryabkov'],
#  ['john mahama', 'john dramani mahama'],
#  ['ukrainian engineer', 'ukrainian engineers'],
#  ['vyacheslav gladkov', 'viatcheslav gladkov'],
#  ['hungarian government', 'hungary'],
#  ['mustafa jemilev', 'mustafa dzhemilev'],
#  ['william lai', 'lai ching-te'],
#  ['germany', 'german government'],
#  ['valery', 'valeriy'],
#  ['kirill rogov', 'vladimir rogov'],
#  ['french government', 'france'],
#  ['mykhailo fedorov', 'mykhailo federov'],
#  ['council of europe', 'european council'],
#  ['maksym kozytskyi', 'maksym kosytskyi'],
#  ['un independent international commission of inquiry on ukraine',
#   'independent international commission of inquiry on ukraine'],
#  ['british defence intelligence', 'british military intelligence'],
#  ['russian administration', 'russian-appointed administration'],
#  ['german chancellor olaf scholz', 'olaf scholz'],
#  ['jaroslaw kaczynski', 'jarosław kaczyński'],
#  ['richard justin kemp', 'richard kemp'],
#  ['fauzan al-rasyid', 'fauzan al rasyid'],
#  ['valery aleksandrovich fadeev', 'valery nikolaevich falkov'],
#  ['russian embassy', 'russian embassy in washington'],
#  ['kremlin', 'the kremlin'],
#  ['main directorate of the state emergency service of ukraine in the zaporizhzhia region',
#   "ukraine's emergency services"],
#  ['yevhen radchenko', 'yevhen rvachov'],
#  ['vladimir soloviev', 'vladimir solovyov'],
#  ['bernardo arevalo', 'bernardo arévalo'],
#  ['alejandro n. mayorkas', 'alejandro mayorkas'],
#  ['ldpr', 'liberal democratic party of russia'],
#  ['armenian government', 'armenian administration'],
#  ['kost bondarenko', 'oleg bondarenko'],
#  ['maxim kositsky', 'maxim kozitsky'],
#  ["venezuela's opposition", 'venezuelan opposition'],
#  ['fumio kishida', 'fumo kishida'],
#  ['russian-appointed official in kherson',
#   'russian-appointed official in kherson region'],
#  ['finance ministry of russia', 'russian ministry of finance'],
#  ['artem lysogor', 'artem lysohor'],
#  ['dmitri oreshkin', 'dmitry oreshkin'],
#  ['emmanuel macron', 'french president emmanuel macron'],
#  ['asad majeed khan'],
#  ['masood khan'],
#  ['smer-ssd', 'smer'],
#  ['sergei lezhnev', 'sergei leshchenko'],
#  ['natalia kulichenko', 'natalya komarova'],
#  ['russian telegram channel two majors', 'two majors telegram channel'],
#  ['andrey vorobyov', 'andrei vorobyov'],
#  ['kyiv post', 'the kyiv independent'],
#  ['vladimir vysotsky', 'vladimir semenovich vysotsky'],
#  ['philip m. breedlove', 'philip breedlove'],
#  ['john herbst', 'john e. herbst'],
#  ['boris gryzlov', 'boris grozovski'],
#  ['artem dekhtiarenko', 'artem dekhtyarenko'],
#  ['emmerson mnangagwa', 'emerson mnangagwa'],
#  ['viktoriia halitsyna', 'viktoriia halitsina'],
#  ['kirill', 'patriarch kirill'],
#  ['moreno ocampo', 'luis moreno ocampo'],
#  ['wolodymyr zelensky', 'wolodimir zelenski'],
#  ['anatoly', 'anatoliy'],
#  ['khrystyna kit', 'chrystyna kit'],
#  ['yuri malashko', 'yurii malashko'],
#  ['nestor shufrych', 'nestor shufrich'],
#  ['volodymyr rybalkin', 'volodymyr rybak'],
#  ['alexander khinshtein', 'alexander khinstein'],
#  ['alexei morozov', 'andrei morozov'],
#  ['pro-russian separatist groups', 'vostok battalion'],
#  ["ukraine's separate 3rd assault brigade",
#   "ukraine's 3rd separate assault brigade"],
#  ['rastislav káčer', 'rastislav kacer'],
#  ['aleksandar vucic', 'vucic'],
#  ['aleksandr bastrikin', 'alexander bastrykin'],
#  ['russian-installed authorities in zaporizhzhia',
#   'russian-appointed officials in occupied zaporizhzhia'],
#  ['poland', 'polish government'],
#  ['general ivan popov', 'ivan popov'],
#  ['ukrainian organization', 'russian-speaking community in ukraine'],
#  ['wang yi', 'chinese foreign minister wang yi'],
#  ['sergey tolkachev', 'serhiy tolstov'],
#  ['roman svytan', 'roman svitan'],
#  ['alexander abramov', 'ivan avramov'],
#  ['stian jenssen', 'stian jensen'],
#  ['german bundeswehr', 'bundeswehr'],
#  ['carole grimaud potter', 'carole grimaud'],
#  ['viktor orbán', 'viktor orban'],
#  ['olexander syrskyi', 'alexander syrskyi'],
#  ['royal united services institute',
#   'royal united services institute for defense and security studies'],
#  ['oleg matveychev', 'oleg matytsin'],
#  ['bola ahmed tinubu', 'bola tinubu'],
#  ['economic community of west african states', 'ecowas'],
#  ['dmitri rogozine', 'dmitry rogozin'],
#  ['ukrainian-speaking community', 'ukrainian society'],
#  ['masi nayem', 'masi nayyem'],
#  ['anastasia saksaganski', 'anastasia saksagansky'],
#  ['general abdourahmane tchiani', 'abdourahmane tchiani'],
#  ['oleg syniehubov', 'oleg synegubov'],
#  ['exiled mayor of melitopol', 'mayor of melitopol'],
#  ['andreï pertsev', 'andrei pertsev'],
#  ['ilham aliyev', 'rukhin aliyev'],
#  ['franz-stefan gady', 'franz stefan-gady'],
#  ['s jaishankar', 'subramanyam jaishankar'],
#  ['social democratic party (spd)', 'spd'],
#  ['sergei kiriyenko', 'sergey kiriyenko'],
#  ['alexander sidjakin', 'alexander sidyakin'],
#  ['government of india', 'indian government'],
#  ['zimbabwe african national union-patriotic front', 'zanu pf'],
#  ['international community', 'united nations commission'],
#  ["alexei navalny's fbk", "alexey navalny's fbk"],
#  ['embassy of the russian federation', 'russian embassy in london'],
#  ['ilya yevlach', 'ilya yevlasch'],
#  ['valery saksagansky', 'valeriy saksaganski'],
#  ['darya lantratov', 'daria lantratov'],
#  ['pavlo lazarenko', 'pavel latushko'],
#  ['yaroslav zhelezniak', 'jaroslaw zheleznyak'],
#  ['residents of donetsk', 'residents in donetsk and luhansk'],
#  ['oleksandr pivnenko', 'oleksandr navarenko'],
#  ['vitali khotsenko', 'vitaly khotsenko'],
#  ['serhii hromenko', 'serhii hrabovsky'],
#  ['yellow ribbon movement', 'yellow ribbon resistance movement'],
#  ['general david petraeus', 'david petraeus'],
#  ['pyotr tolstoy', 'pjotr tolstoj'],
#  ['legion freedom of russia', 'freedom of russia legion'],
#  ['international court of justice'],
#  ['international criminal court'],
#  ['party of regions', 'party of the regions'],
#  ['galina lugovaya', 'galina lugova'],
#  ['bulaev sergei', 'nicolai bulaev'],
#  ['anonymous author', 'an unknown author'],
#  ['dmitrieva tatyana', 'tatyana dmitrieva'],
#  ['residents and ukrainian activists',
#   'local residents and ukrainian activists'],
#  ['erik møse', 'erik mose'],
#  ['anton korynevych', 'anton korynevich'],
#  ['volodymyr shevchenko', 'kyrylo shevchenko'],
#  ['gennady zyuganov', 'genadiy zyuganov'],
#  ['nicolas maduro', 'nicolás maduro'],
#  ['grigorij meseznikov', 'grigorij mesežnikov'],
#  ['andriy chernyak', 'andrii cherniak'],
#  ['andrey kozenko', 'andriy kuzmenko'],
#  ['russian occupation administration in kherson',
#   'kherson oblast occupation administration'],
#  ['oleh kipar', 'oleh kiper'],
#  ['federal ministry of defense', 'federal ministry of defense of germany'],
#  ['spain', 'spanish government'],
#  ['sarah wagenknecht', 'sahra wagenknecht'],
#  ['serhii borzov', 'serhiy borzov'],
#  ['pakistan muslim league-nawaz', 'pakistan muslim league (nawaz)'],
#  ['serhiy buriak', 'sergey bubka'],
#  ['french diplomacy', 'diplomacy of france'],
#  ['olha stefanischyna', 'olha stefanishyna'],
#  ['ivan fedorov', 'ivan fyodorov'],
#  ['rafael grossi', 'rafael mariano grossi'],
#  ['oleg krioutchkov', 'oleg kryuchkov'],
#  ['harald jepsen', 'harald hartvig jepsen'],
#  ["ukraine's ministry of legal affairs", 'ministry of justice of ukraine'],
#  ['amadou abramane', 'amadou abdramane'],
#  ['yoon sukgyeol', 'yoon suk yeol'],
#  ['vyacheslav volodin', 'vyacheslav volodine'],
#  ['sergei markov', 'sergey markov'],
#  ['roman starovoyt', 'roman starovoit'],
#  ['sébastien lecornu', 'sebastien lecornu'],
#  ['un general assembly', 'united nations general assembly'],
#  ['russian embassy in dhaka', 'russian embassy in bangladesh'],
#  ['alberto nunez feijoo', 'alberto núñez feijóo'],
#  ['petro andriushchenko', 'petro andrushchenko'],
#  ['yulia rolikova', 'joelia rolikova'],
#  ['robert telus', 'robert telyus'],
#  ['gitanas nausėda', 'gitanas nauseda'],
#  ['yevgeny prigozhin', 'yevgeniy prigozhin'],
#  ['maxim grigoriev', 'maxime grigoryev'],
#  ['oleksii pedosenko', 'oleksii podolsky'],
#  ['ali bongo ondimba', 'ali bongo'],
#  ['leonid pasechnik', 'leonid ivanovich pasechnik'],
#  ['andriy zagorodnyuk', 'andriy kozintchouk'],
#  ['ukrainian navy', 'ukrainian naval forces'],
#  ['vladislav shapshá', 'vladyslav shapsha'],
#  ['konstantin kalachov', 'konstantin kalachev'],
#  ['mateusz morawiecki', 'polish prime minister mateusz morawiecki'],
#  ['mikhaïl razvojaev', 'mikhail razvojaev'],
#  ['moldovan foreign ministry', 'foreign ministry of moldova'],
#  ['petro poroshenko', 'pyotr poroshenko'],
#  ['aleksandr malkevich', 'mikhail malyshev'],
#  ['petr kotin', 'petro kotin'],
#  ['svyatoslav kalikhaev', 'sviatoslav kolyhaiev'],
#  ['federal state unitary enterprise rami ria novosti',
#   'federal state unitary enterprise rami "ria novosti"'],
#  ['aleksandr bogomaz', 'alexander bogomaz'],
#  ['oleksiy kushch', 'aleksey kushch'],
#  ['oleh synehubov', 'oleh syniehubov'],
#  ['christian democratic union (cdu)'],
#  ['cdu/csu parliamentary group'],
#  ['oleksandra matviichuk', 'oleksandra matviychuk'],
#  ['nicholas sarkozy', 'nicolas sarkozy'],
#  ['ilya ponomarov', 'ilya ponomarev'],
#  ['the moscow times', 'moscow times'],
#  ['yurii bielousov', 'yuriy belousov'],
#  ['vitaliy koval', 'vitaly koval'],
#  ['government of sweden', 'swedish government'],
#  ['andrei troshev', 'andrey troshev'],
#  ['muhammed bin salman', 'mohammed bin salman'],
#  ['federal government of germany', 'german federal government'],
#  ['olena zelensky', 'olena zelenska'],
#  ['wojciech konończuk', 'wojciech kononczuk'],
#  ['krišjānis kariņš', 'krisjanis karins'],
#  ['halyna', 'halyna shylina'],
#  ['golos election monitoring organization', 'election-monitoring ngo golos'],
#  ['maria lvova-belova', 'maria alekseyevna lvova-belova'],
#  ['canada', 'government of canada'],
#  ['us national security spokesperson john kirby',
#   'white house national security spokesman john kirby'],
#  ['dmytro orlov', 'stanislav orlov'],
#  ['third separate assault brigade', '3rd separate assault brigade'],
#  ['mykahilo podolyak'],
#  ['general oleksandr tarnawskiji'],
#  ['kremlin-installed officials'],
#  ['mychailo podolyak'],
#  ['kiev supporters and pro-westerners'],
#  ['dmytro kouleba'],
#  ['yuriy pohulyaiko'],
#  ['mychailo podoljak'],
#  ["ukraine's gur intelligence agency"],
#  ['ukrainian security sources'],
#  ['dmitri kuleba'],
#  ['andrii yusov'],
#  ['ukrainian military leadership'],
#  ['oleksiy arestovych'],
#  ['yuri ignat'],
#  ['theodoros christoudias'],
#  ['celso amorim'],
#  ['rachel homer'],
#  ['ashok gulati riya das'],
#  ['yuriy mysiagin'],
#  ['vadim pistrinciuc'],
#  ['ukrainian public prosecutor'],
#  ['georgy petrovich kamnev'],
#  ['conflict intelligence team'],
#  ['central african republic government'],
#  ['anonymous engineers'],
#  ['andrii zalivskyi'],
#  ['yevhen'],
#  ['masanja kadogosa'],
#  ['kara hope'],
#  ['democrats'],
#  ['anwaar-ul-haq kakar'],
#  ['regional electoral commission'],
#  ['istván hegedűs'],
#  ['foreign ministers of canada, france, germany, italy, japan, the united kingdom and the united states of america, as well as the high representative of the european union'],
#  ['oleksandr riabchenko'],
#  ['abdurrahmani chiani'],
#  ['javier milei'],
#  ['awaludin iqbal'],
#  ['frans kapofi'],
#  ['vuk vuksanovic'],
#  ['mark galeotti'],
#  ['dmytro lysiuk'],
#  ['volodymyr grutman'],
#  ['boris kagarlitsky'],
#  ['lithuania'],
#  ['hanna hopko'],
#  ['serbian expert'],
#  ['harold chambers'],
#  ['suella braverman'],
#  ['irina tsukerman'],
#  ['russian ultranationalists'],
#  ['anonymous american officials'],
#  ['boris johnson'],
#  ['kyiv angels'],
#  ['wayne jordash'],
#  ['dmitry pletenchuk'],
#  ['steven horrell'],
#  ['election commission of pakistan'],
#  ['volodymyr fessenko'],
#  ['russian plant administration'],
#  ['sergiy kyslytsya'],
#  ['financial times'],
#  ['gerard toal'],
#  ['glenn greenwald'],
#  ['kurt volker'],
#  ['natasha'],
#  ['georgi buiko'],
#  ['yury yanysh'],
#  ['atlantic council'],
#  ['yana gelmel'],
#  ['federal ministry of agriculture'],
#  ['kherson regional council'],
#  ['hungarian foreign minister'],
#  ['abdelmadjid tebboune'],
#  ['alina'],
#  ['penny wong'],
#  ['john f kirby'],
#  ['maksut shadaev'],
#  ['rahul gandhi'],
#  ['klaus iohannis'],
#  ['olha kharlan'],
#  ['steven anderson'],
#  ['yves plasseraud'],
#  ['karim a. a. khan'],
#  ['marie mendras'],
#  ['andrejs vorbyov'],
#  ['hans horan'],
#  ["people's council of the dpr"],
#  ['leendert verbeek'],
#  ['douglas mwonzora'],
#  ['yeven olexienko'],
#  ['kevin limonier'],
#  ['stanislav pozdnyakov'],
#  ['sergey parkhomenko'],
#  ['boris pistorius'],
#  ['shehbaz sharif'],
#  ['kristina kvien'],
#  ['oleksandr solontai'],
#  ['thomas tayebwa'],
#  ['seth krummrich'],
#  ['ramzan kadyrov'],
#  ['social democrats'],
#  ['gleb nikitin'],
#  ['gript'],
#  ['vyacheslav kantor'],
#  ['serhii halushko'],
#  ['adrii'],
#  ['diane seyr'],
#  ['japan'],
#  ['ruslan'],
#  ['human rights organizations'],
#  ['oleg nikolenko'],
#  ['oleksandr'],
#  ['alexey likhachev'],
#  ['anna surovikin'],
#  ['valery gerasimov'],
#  ['rybar telegram channel'],
#  ['armatec survivability'],
#  ['gabrielle reid'],
#  ['pavel latushka'],
#  ['oleg tsarev'],
#  ['rodney dixon'],
#  ['marcus faber'],
#  ['donbas miners'],
#  ['margo grosberg'],
#  ['oleg sacharow'],
#  ['pinar demircan'],
#  ['jeanne shaheen'],
#  ['roberto vannacci'],
#  ['tom malinowski'],
#  ['elections resource centre'],
#  ['olha kartashova'],
#  ['oleksii antoniuk'],
#  ['vladimir kudrytsky'],
#  ['guido crosetto'],
#  ['center for a new american security'],
#  ['alexander asafov'],
#  ['denis manturov'],
#  ['valentina matviyenko'],
#  ['yaku perez'],
#  ['zsolt schemien'],
#  ['nicholas kristof'],
#  ['saint vincent and the grenadines'],
#  ['boris grishin'],
#  ['serhiy gayday'],
#  ['pascale christine baeriswyl'],
#  ['national cyber security centre'],
#  ['ukrainian agriculture ministry'],
#  ['indian media'],
#  ['peter welch'],
#  ['ferlon christians'],
#  ['russian embassy in canada'],
#  ['denise brown'],
#  ['julie mayfield'],
#  ['fayez al-duwairi'],
#  ['kherson avtodor enterprise'],
#  ['federal council of switzerland'],
#  ['ilya remeslo'],
#  ['sofia'],
#  ['christian mölling'],
#  ['guy parmelin'],
#  ['nikcenter'],
#  ['john roberts'],
#  ['aleks szczerbiak'],
#  ['yale university'],
#  ['atezh group'],
#  ['steven cook'],
#  ['marsh'],
#  ['kit klarenberg'],
#  ['james bezan'],
#  ['robert torricelli'],
#  ['ana brnabic'],
#  ['nikita borodin'],
#  ['natalka cmoc'],
#  ['alexey danilov'],
#  ['herfried münkler'],
#  ['goran petronijevic'],
#  ['sara nanni'],
#  ['nnenna nwabufo'],
#  ['kaspersky'],
#  ['jim geraghty'],
#  ['mikhaela'],
#  ['sherrod brown'],
#  ['yevgeniy golovchenko'],
#  ['alexei dyumin'],
#  ['ukrainian military administration'],
#  ['house foreign affairs republican aide'],
#  ['armenia'],
#  ['lyudmyla husseinova'],
#  ['new people'],
#  ['yurri clavilier'],
#  ['andrei mordvichev'],
#  ['jefferson goyburo'],
#  ['katrin seidel'],
#  ['rafał kęsek'],
#  ['volodymyr hranovsky'],
#  ['sergei rudskoy'],
#  ['thomas haldenwang'],
#  ['oleksandr vilkul'],
#  ['harald wilimsky'],
#  ['marija pejčinović burić'],
#  ['mahamudu bawumia'],
#  ['musa ebomhiana'],
#  ['alexander titov'],
#  ['association of eritrean clubs in stuttgart'],
#  ['william ruto'],
#  ['western countries'],
#  ['john stremlau'],
#  ['ministry of energy of ukraine'],
#  ['theresa may'],
#  ['slomo koves'],
#  ['eric chu'],
#  ['matthew rojansky'],
#  ['valentín'],
#  ['michael newton'],
#  ['joel maiyo'],
#  ['geir flikke'],
#  ['cem özdemir'],
#  ['association of ukrainians in portugal'],
#  ['mumtaz zahra baloch'],
#  ['alexandre', 'alexandr'],
#  ['national electoral council of ecuador'],
#  ['vjosa osmani'],
#  ['david hambling'],
#  ['47-year-old woman from yekaterinburg'],
#  ['currency traders'],
#  ['vladyslav vlasiuk'],
#  ['ukrainska pravda'],
#  ['akif cagatay kilic'],
#  ['thea dunlevie'],
#  ['igor konashenkov'],
#  ['milorad dodik'],
#  ['sergei sumlenny'],
#  ['thomas byrne'],
#  ['james nixey'],
#  ['bae systems'],
#  ['tumso abdurakhmanov'],
#  ['yulia tymoshenko'],
#  ['głos organization'],
#  ['goran simpraga'],
#  ['political experts'],
#  ['pavel lysianskii'],
#  ['qasy-jomart toqaev'],
#  ['servant of the people faction'],
#  ['eleonora tanacova'],
#  ['dmytro pletenchuk'],
#  ['republican legislators'],
#  ['piers pigou'],
#  ['ihor isichenko'],
#  ['petro chernyk'],
#  ['stephen nix'],
#  ['trout unlimited'],
#  ['warsaw residents'],
#  ['steny hoyer'],
#  ['aleksandr savitsky'],
#  ['danilin pawel'],
#  ['nirmala sitharaman'],
#  ['uk government'],
#  ['maria'],
#  ['shoaib shaheen'],
#  ['serhyi haidai'],
#  ['prigozhin supporters'],
#  ['christian wehrschütz'],
#  ['naeem haider panjhuta'],
#  ['konstantin mashovets'],
#  ['slovakia'],
#  ['sylvia limmer'],
#  ['vadym boichenko'],
#  ['sebastian rötters'],
#  ['nataliia humeniuk'],
#  ['russian opposition media outlet verstka'],
#  ['mahmoud abbas'],
#  ['alexandra prokopenko'],
#  ['guinea'],
#  ['arsen temirayev'],
#  ['sasha'],
#  ['frederick kagan'],
#  ['patrick ryder'],
#  ['vishwa hindu parishad'],
#  ['kirill kabanov'],
#  ['moldova'],
#  ['mykola syrii'],
#  ['ihor kozii'],
#  ['mate paczolay'],
#  ['bulgarian farmers union'],
#  ['mikhail oseyevsky'],
#  ['oskar fontaine'],
#  ['andrey kanashevich'],
#  ['cameron dugmore'],
#  ['ashot arutiunian'],
#  ['alexander cummings'],
#  ['oleksandr rodyansky'],
#  ['alex rossi'],
#  ['ilya butkevych'],
#  ['ignazio cassis'],
#  ['ruslan stefanchuk'],
#  ['atrocity crimes advisory group'],
#  ['ukrainian mechanics'],
#  ['borys tarasiuk'],
#  ['peter brandt'],
#  ['sevastian boiko'],
#  ['florian hahn'],
#  ['olga bura'],
#  ['paul kamenar'],
#  ['jocelyn trainer'],
#  ['tomas janeliūnas'],
#  ['dimitri laskaris'],
#  ['farhad mammadov'],
#  ['garry kasparov'],
#  ['white house'],
#  ['andy harris'],
#  ['patricia bullrich'],
#  ['russian politicians and spin doctors'],
#  ["ukraine's southern military command"],
#  ['philip ricker'],
#  ['bashar al-assad'],
#  ['ramón sáez'],
#  ['marqarita simonyan'],
#  ['donetsk institute for social research and political analysis'],
#  ['alexandra chyczij'],
#  ['konstyantyn mashovets'],
#  ['moussa faki mahamat'],
#  ['david greenberg'],
#  ['pavel lisyansky'],
#  ['epifanio'],
#  ['russian occupation authorities'],
#  ['icu'],
#  ['zimbabwe electoral commission'],
#  ['atesh'],
#  ['batu kutelia'],
#  ['danuta dlugolecka'],
#  ['andrzej duda'],
#  ['all-ukrainian union svoboda'],
#  ['ed markey'],
#  ['brian raftopoulos'],
#  ['carsten linnemann'],
#  ['center for political sociology'],
#  ['hacker activists'],
#  ['kiribati'],
#  ['jurij ihnat'],
#  ['tomas krissak'],
#  ['intelligence and security committee of parliament'],
#  ['metropolitan epiphany'],
#  ['tory strategists'],
#  ['petr pavel'],
#  ['ana lovrić'],
#  ['russian volunteer corps'],
#  ['mart wendla'],
#  ['christine hackenesch'],
#  ['jeffrey sachs'],
#  ['herbert kickl'],
#  ['reuters'],
#  ['bishop lazi'],
#  ['shaun burnie and jan vande putte'],
#  ['nova resistência'],
#  ['russian orthodox church'],
#  ['zdf'],
#  ['vít dostál'],
#  ['isamaa'],
#  ['romanian government'],
#  ['united nations human rights council'],
#  ['valery pustovoitenko'],
#  ['diana atamaint'],
#  ['david scheffer'],
#  ['tatarigami_ua'],
#  ['arab and turkmen opponents'],
#  ['william burns'],
#  ['bloomberg'],
#  ['margus tsahkna'],
#  ['gavin wilde'],
#  ['freedom party of austria'],
#  ['péter szijjártó'],
#  ['kurdistan democratic party'],
#  ['parliament of ghana'],
#  ['national elections authority'],
#  ['seymour hersh'],
#  ['government of germany'],
#  ['alexander brod'],
#  ['robert mueller'],
#  ['melanie phillips'],
#  ['gustavo sénéchal de goffredo junior'],
#  ['steve anderson'],
#  ['serhii khlan'],
#  ['revolutionary socialist vanguard'],
#  ['oleg drozdov'],
#  ['alice jill edwards'],
#  ['igar tyshkevich'],
#  ['balkan-ukrainian cooperation network'],
#  ['oleg kiper'],
#  ['yana lantratova'],
#  ['ukrainian osint specialist'],
#  ['maryna liuta'],
#  ['nobel peace laureates'],
#  ['center for democratic integrity'],
#  ['oleksandr yefremov'],
#  ['ori givati'],
#  ['richard barrons'],
#  ['dmitry degterev'],
#  ['dmitri kuzents'],
#  ['trina saha'],
#  ['cnn'],
#  ['justin bronk'],
#  ['federal tax service for the tyumen region'],
#  ['gwynne shotwell'],
#  ['alyona lunyova'],
#  ['german foreign ministry'],
#  ['eisenhower media network'],
#  ['taylor-greene'],
#  ['linda yaccarino'],
#  ['sadc election observation mission'],
#  ['oleh soskin'],
#  ['joel benenson'],
#  ['rob lee'],
#  ['natalya shemetova'],
#  ['chido onumah'],
#  ['mikhail teplinsky'],
#  ['blair bowie'],
#  ['national bank of ukraine'],
#  ['latin american states'],
#  ['putin administration'],
#  ['alsou maganova'],
#  ['united states intelligence officials'],
#  ['hryhorii nemyria'],
#  ['roy cooper'],
#  ['metodije'],
#  ['ivan sestryvatovsky'],
#  ['renat ivanovich karchaa'],
#  ['dan hodgson'],
#  ['gerardo berthin'],
#  ['yevhen dykyi'],
#  ['luc michel'],
#  ['mike johnson'],
#  ['ararat mirzoyan'],
#  ['olexij resnikow'],
#  ['russian occupation forces'],
#  ['moira chepakiror'],
#  ['volodymyr demiokhin'],
#  ['uk intelligence officials'],
#  ['michael rubin'],
#  ['western allies'],
#  ['sebastian pitoń'],
#  ['steve wright'],
#  ['south korean president yoon suk yeol'],
#  ['klayn john preston iv'],
#  ['cesar azpilicueta'],
#  ['andriy magera'],
#  ['revolutionary communist international tendency'],
#  ['oleg artamonov'],
#  ['lilia podkopayeva'],
#  ['yuri chekunov'],
#  ['volodymyr malynkovych'],
#  ['pat ryder'],
#  ['russian state atomic energy corporation rosatom'],
#  ['roskomnadzor'],
#  ['uffe dreesen'],
#  ['boris dralyuk'],
#  ['andrey ivanovich rogatnev'],
#  ['greenpeace'],
#  ['baltic countries'],
#  ["russia's ruling party"],
#  ['alexander tochenov'],
#  ['beverley oching'],
#  ['alexandra fokina'],
#  ['karina yakubova'],
#  ['david cohnen'],
#  ['transdnistria'],
#  ['dmitry novikov'],
#  ['oleg nesterov'],
#  ['ella libanova'],
#  ['mycle schneider'],
#  ['andrei kravchenko'],
#  ['konstantin kosachev'],
#  ['arno klarsfeld'],
#  ['ivo mijnssen'],
#  ['the west'],
#  ['yurii shchyhol'],
#  ['robert westerholt'],
#  ['valeriy shershen'],
#  ['german intellectuals'],
#  ['vostok militia commander'],
#  ['mustafa kamal'],
#  ['us official'],
#  ['olivér várhelyi'],
#  ['ruslan koshulynsky'],
#  ['united nations'],
#  ['alexander nekrassov'],
#  ['jaap de hoop scheffer'],
#  ['marcus keupp'],
#  ['ivan antypensko'],
#  ['samuel b. hoff'],
#  ["european union's spanish presidency"],
#  ['immigration services agency of japan'],
#  ['yury mysyagin'],
#  ['jozef hrabina'],
#  ['vasily piskarev'],
#  ['andreas kluth'],
#  ['andrei p. tsygankov'],
#  ['thane soe'],
#  ['davit totadze'],
#  ['lia becker'],
#  ['diana panchenko'],
#  ['tim benton'],
#  ['grant shapps'],
#  ['southern african development community'],
#  ['tiny cox'],
#  ['lata nott'],
#  ['russian embassy in budapest'],
#  ['konstantin skorkin'],
#  ['sanjeev chopra'],
#  ['dmytro razumkov'],
#  ['azerbaijani government'],
#  ['josef bires'],
#  ['henrique dominguez'],
#  ['zurab makiev'],
#  ['kamil basaj'],
#  ['friends of the eel river'],
#  ['valentine gorshkova'],
#  ["russia's gru and fsb intelligence agencies"],
#  ['giorgio deschi'],
#  ['tanya kondakova'],
#  ['rybar'],
#  ['dylan white'],
#  ['douglas webber'],
#  ['hal brands'],
#  ['alexey paramonov'],
#  ['dmytro tabatschnik'],
#  ['brics forum advisor'],
#  ["nicolas maduro's administration"],
#  ['human rights watch'],
#  ['kn pandita'],
#  ['oleksiy haran'],
#  ['wisconsin institute for law and liberty'],
#  ['david silbey'],
#  ['mohamed kamal'],
#  ['abigail spanberger'],
#  ['chinese foreign ministry'],
#  ['vadim prokhorov'],
#  ['elina beketova'],
#  ['oleksandra romantsova'],
#  ['mikhail'],
#  ['biden administration'],
#  ['vadym denysenko'],
#  ['tymofiy mylovanov'],
#  ['lidiya melnyk'],
#  ['communist party usa'],
#  ...]

# %%
positive_results = []
for sublist in stakeholder_clusters_final:
    for i in range(len(sublist)):
        for j in range(i + 1, len(sublist)):
            positive_results.append((sublist[i], sublist[j]))

positive_results
# Out:
# [('central elections commission of russia', "russia's elections commission"),
#  ('central elections commission of russia',
#   'russian central election commission'),
#  ('central elections commission of russia',
#   'the central election commission of russia'),
#  ('central elections commission of russia',
#   'central election commission of the russian federation'),
#  ('central elections commission of russia',
#   'central electoral commission of the russian federation'),
#  ('central elections commission of russia',
#   'central election commission of russia'),
#  ('central elections commission of russia',
#   'moscow regional election committee'),
#  ('central elections commission of russia', 'russian election commission'),
#  ('central elections commission of russia',
#   "russia's central election commission"),
#  ('central elections commission of russia', "russia's election commission"),
#  ('central elections commission of russia',
#   'russian central electoral commission'),
#  ('central elections commission of russia',
#   "russia's central elections commission"),
#  ('central elections commission of russia', 'russian electoral commission'),
#  ('central elections commission of russia', 'russian election authorities'),
#  ('central elections commission of russia',
#   'central electoral commission of russia'),
#  ('central elections commission of russia',
#   'election commission of tsentralny of the russian federation'),
#  ('central elections commission of russia', "moscow's electoral commission"),
#  ('central elections commission of russia', "moscow's election commission"),
#  ('central elections commission of russia', 'moscow city election commission'),
#  ("russia's elections commission", 'russian central election commission'),
#  ("russia's elections commission",
#   'the central election commission of russia'),
#  ("russia's elections commission",
#   'central election commission of the russian federation'),
#  ("russia's elections commission",
#   'central electoral commission of the russian federation'),
#  ("russia's elections commission", 'central election commission of russia'),
#  ("russia's elections commission", 'moscow regional election committee'),
#  ("russia's elections commission", 'russian election commission'),
#  ("russia's elections commission", "russia's central election commission"),
#  ("russia's elections commission", "russia's election commission"),
#  ("russia's elections commission", 'russian central electoral commission'),
#  ("russia's elections commission", "russia's central elections commission"),
#  ("russia's elections commission", 'russian electoral commission'),
#  ("russia's elections commission", 'russian election authorities'),
#  ("russia's elections commission", 'central electoral commission of russia'),
#  ("russia's elections commission",
#   'election commission of tsentralny of the russian federation'),
#  ("russia's elections commission", "moscow's electoral commission"),
#  ("russia's elections commission", "moscow's election commission"),
#  ("russia's elections commission", 'moscow city election commission'),
#  ('russian central election commission',
#   'the central election commission of russia'),
#  ('russian central election commission',
#   'central election commission of the russian federation'),
#  ('russian central election commission',
#   'central electoral commission of the russian federation'),
#  ('russian central election commission',
#   'central election commission of russia'),
#  ('russian central election commission', 'moscow regional election committee'),
#  ('russian central election commission', 'russian election commission'),
#  ('russian central election commission',
#   "russia's central election commission"),
#  ('russian central election commission', "russia's election commission"),
#  ('russian central election commission',
#   'russian central electoral commission'),
#  ('russian central election commission',
#   "russia's central elections commission"),
#  ('russian central election commission', 'russian electoral commission'),
#  ('russian central election commission', 'russian election authorities'),
#  ('russian central election commission',
#   'central electoral commission of russia'),
#  ('russian central election commission',
#   'election commission of tsentralny of the russian federation'),
#  ('russian central election commission', "moscow's electoral commission"),
#  ('russian central election commission', "moscow's election commission"),
#  ('russian central election commission', 'moscow city election commission'),
#  ('the central election commission of russia',
#   'central election commission of the russian federation'),
#  ('the central election commission of russia',
#   'central electoral commission of the russian federation'),
#  ('the central election commission of russia',
#   'central election commission of russia'),
#  ('the central election commission of russia',
#   'moscow regional election committee'),
#  ('the central election commission of russia', 'russian election commission'),
#  ('the central election commission of russia',
#   "russia's central election commission"),
#  ('the central election commission of russia', "russia's election commission"),
#  ('the central election commission of russia',
#   'russian central electoral commission'),
#  ('the central election commission of russia',
#   "russia's central elections commission"),
#  ('the central election commission of russia', 'russian electoral commission'),
#  ('the central election commission of russia', 'russian election authorities'),
#  ('the central election commission of russia',
#   'central electoral commission of russia'),
#  ('the central election commission of russia',
#   'election commission of tsentralny of the russian federation'),
#  ('the central election commission of russia',
#   "moscow's electoral commission"),
#  ('the central election commission of russia', "moscow's election commission"),
#  ('the central election commission of russia',
#   'moscow city election commission'),
#  ('central election commission of the russian federation',
#   'central electoral commission of the russian federation'),
#  ('central election commission of the russian federation',
#   'central election commission of russia'),
#  ('central election commission of the russian federation',
#   'moscow regional election committee'),
#  ('central election commission of the russian federation',
#   'russian election commission'),
#  ('central election commission of the russian federation',
#   "russia's central election commission"),
#  ('central election commission of the russian federation',
#   "russia's election commission"),
#  ('central election commission of the russian federation',
#   'russian central electoral commission'),
#  ('central election commission of the russian federation',
#   "russia's central elections commission"),
#  ('central election commission of the russian federation',
#   'russian electoral commission'),
#  ('central election commission of the russian federation',
#   'russian election authorities'),
#  ('central election commission of the russian federation',
#   'central electoral commission of russia'),
#  ('central election commission of the russian federation',
#   'election commission of tsentralny of the russian federation'),
#  ('central election commission of the russian federation',
#   "moscow's electoral commission"),
#  ('central election commission of the russian federation',
#   "moscow's election commission"),
#  ('central election commission of the russian federation',
#   'moscow city election commission'),
#  ('central electoral commission of the russian federation',
#   'central election commission of russia'),
#  ('central electoral commission of the russian federation',
#   'moscow regional election committee'),
#  ('central electoral commission of the russian federation',
#   'russian election commission'),
#  ('central electoral commission of the russian federation',
#   "russia's central election commission"),
#  ('central electoral commission of the russian federation',
#   "russia's election commission"),
#  ('central electoral commission of the russian federation',
#   'russian central electoral commission'),
#  ('central electoral commission of the russian federation',
#   "russia's central elections commission"),
#  ('central electoral commission of the russian federation',
#   'russian electoral commission'),
#  ('central electoral commission of the russian federation',
#   'russian election authorities'),
#  ('central electoral commission of the russian federation',
#   'central electoral commission of russia'),
#  ('central electoral commission of the russian federation',
#   'election commission of tsentralny of the russian federation'),
#  ('central electoral commission of the russian federation',
#   "moscow's electoral commission"),
#  ('central electoral commission of the russian federation',
#   "moscow's election commission"),
#  ('central electoral commission of the russian federation',
#   'moscow city election commission'),
#  ('central election commission of russia',
#   'moscow regional election committee'),
#  ('central election commission of russia', 'russian election commission'),
#  ('central election commission of russia',
#   "russia's central election commission"),
#  ('central election commission of russia', "russia's election commission"),
#  ('central election commission of russia',
#   'russian central electoral commission'),
#  ('central election commission of russia',
#   "russia's central elections commission"),
#  ('central election commission of russia', 'russian electoral commission'),
#  ('central election commission of russia', 'russian election authorities'),
#  ('central election commission of russia',
#   'central electoral commission of russia'),
#  ('central election commission of russia',
#   'election commission of tsentralny of the russian federation'),
#  ('central election commission of russia', "moscow's electoral commission"),
#  ('central election commission of russia', "moscow's election commission"),
#  ('central election commission of russia', 'moscow city election commission'),
#  ('moscow regional election committee', 'russian election commission'),
#  ('moscow regional election committee',
#   "russia's central election commission"),
#  ('moscow regional election committee', "russia's election commission"),
#  ('moscow regional election committee',
#   'russian central electoral commission'),
#  ('moscow regional election committee',
#   "russia's central elections commission"),
#  ('moscow regional election committee', 'russian electoral commission'),
#  ('moscow regional election committee', 'russian election authorities'),
#  ('moscow regional election committee',
#   'central electoral commission of russia'),
#  ('moscow regional election committee',
#   'election commission of tsentralny of the russian federation'),
#  ('moscow regional election committee', "moscow's electoral commission"),
#  ('moscow regional election committee', "moscow's election commission"),
#  ('moscow regional election committee', 'moscow city election commission'),
#  ('russian election commission', "russia's central election commission"),
#  ('russian election commission', "russia's election commission"),
#  ('russian election commission', 'russian central electoral commission'),
#  ('russian election commission', "russia's central elections commission"),
#  ('russian election commission', 'russian electoral commission'),
#  ('russian election commission', 'russian election authorities'),
#  ('russian election commission', 'central electoral commission of russia'),
#  ('russian election commission',
#   'election commission of tsentralny of the russian federation'),
#  ('russian election commission', "moscow's electoral commission"),
#  ('russian election commission', "moscow's election commission"),
#  ('russian election commission', 'moscow city election commission'),
#  ("russia's central election commission", "russia's election commission"),
#  ("russia's central election commission",
#   'russian central electoral commission'),
#  ("russia's central election commission",
#   "russia's central elections commission"),
#  ("russia's central election commission", 'russian electoral commission'),
#  ("russia's central election commission", 'russian election authorities'),
#  ("russia's central election commission",
#   'central electoral commission of russia'),
#  ("russia's central election commission",
#   'election commission of tsentralny of the russian federation'),
#  ("russia's central election commission", "moscow's electoral commission"),
#  ("russia's central election commission", "moscow's election commission"),
#  ("russia's central election commission", 'moscow city election commission'),
#  ("russia's election commission", 'russian central electoral commission'),
#  ("russia's election commission", "russia's central elections commission"),
#  ("russia's election commission", 'russian electoral commission'),
#  ("russia's election commission", 'russian election authorities'),
#  ("russia's election commission", 'central electoral commission of russia'),
#  ("russia's election commission",
#   'election commission of tsentralny of the russian federation'),
#  ("russia's election commission", "moscow's electoral commission"),
#  ("russia's election commission", "moscow's election commission"),
#  ("russia's election commission", 'moscow city election commission'),
#  ('russian central electoral commission',
#   "russia's central elections commission"),
#  ('russian central electoral commission', 'russian electoral commission'),
#  ('russian central electoral commission', 'russian election authorities'),
#  ('russian central electoral commission',
#   'central electoral commission of russia'),
#  ('russian central electoral commission',
#   'election commission of tsentralny of the russian federation'),
#  ('russian central electoral commission', "moscow's electoral commission"),
#  ('russian central electoral commission', "moscow's election commission"),
#  ('russian central electoral commission', 'moscow city election commission'),
#  ("russia's central elections commission", 'russian electoral commission'),
#  ("russia's central elections commission", 'russian election authorities'),
#  ("russia's central elections commission",
#   'central electoral commission of russia'),
#  ("russia's central elections commission",
#   'election commission of tsentralny of the russian federation'),
#  ("russia's central elections commission", "moscow's electoral commission"),
#  ("russia's central elections commission", "moscow's election commission"),
#  ("russia's central elections commission", 'moscow city election commission'),
#  ('russian electoral commission', 'russian election authorities'),
#  ('russian electoral commission', 'central electoral commission of russia'),
#  ('russian electoral commission',
#   'election commission of tsentralny of the russian federation'),
#  ('russian electoral commission', "moscow's electoral commission"),
#  ('russian electoral commission', "moscow's election commission"),
#  ('russian electoral commission', 'moscow city election commission'),
#  ('russian election authorities', 'central electoral commission of russia'),
#  ('russian election authorities',
#   'election commission of tsentralny of the russian federation'),
#  ('russian election authorities', "moscow's electoral commission"),
#  ('russian election authorities', "moscow's election commission"),
#  ('russian election authorities', 'moscow city election commission'),
#  ('central electoral commission of russia',
#   'election commission of tsentralny of the russian federation'),
#  ('central electoral commission of russia', "moscow's electoral commission"),
#  ('central electoral commission of russia', "moscow's election commission"),
#  ('central electoral commission of russia', 'moscow city election commission'),
#  ('election commission of tsentralny of the russian federation',
#   "moscow's electoral commission"),
#  ('election commission of tsentralny of the russian federation',
#   "moscow's election commission"),
#  ('election commission of tsentralny of the russian federation',
#   'moscow city election commission'),
#  ("moscow's electoral commission", "moscow's election commission"),
#  ("moscow's electoral commission", 'moscow city election commission'),
#  ("moscow's election commission", 'moscow city election commission'),
#  ('ukrainian central election commission',
#   "ukraine's central election commission"),
#  ('ukrainian central election commission',
#   'central election commission of ukraine'),
#  ("ukraine's central election commission",
#   'central election commission of ukraine'),
#  ('volodymyr zelenskyy', 'wolodimir selenski'),
#  ('volodymyr zelenskyy', 'volodymyr zelenskyj'),
#  ('volodymyr zelenskyy', 'volodimir zelenski'),
#  ('volodymyr zelenskyy', 'volodymyr zelenskiyy'),
#  ('volodymyr zelenskyy', 'volodymir zelensky'),
#  ('volodymyr zelenskyy', 'volodymyr zelenski'),
#  ('volodymyr zelenskyy', 'vlodomyr zelensky'),
#  ('volodymyr zelenskyy', 'wolodymyr selenskyj'),
#  ('volodymyr zelenskyy', 'vladimir zelensky'),
#  ('volodymyr zelenskyy', 'wolodimir selenskij'),
#  ('volodymyr zelenskyy', 'volodomyr zelenskiy'),
#  ('volodymyr zelenskyy', 'volodymyr zelenskiy'),
#  ('volodymyr zelenskyy', 'vladimir zelenskyy'),
#  ('volodymyr zelenskyy', 'vladimir aleksandrovich zelensky'),
#  ('volodymyr zelenskyy', 'president volodymyr zelensky'),
#  ('volodymyr zelenskyy', 'zelenskyy'),
#  ('volodymyr zelenskyy', 'volodymyr zelensky'),
#  ('volodymyr zelenskyy', 'volodymyr zelenskyi'),
#  ('volodymyr zelenskyy', 'volodimir zelensky'),
#  ('volodymyr zelenskyy', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenskyy', 'vladimir zelenskiy'),
#  ('volodymyr zelenskyy', 'ukrainian president volodymyr zelensky'),
#  ('wolodimir selenski', 'volodymyr zelenskyj'),
#  ('wolodimir selenski', 'volodimir zelenski'),
#  ('wolodimir selenski', 'volodymyr zelenskiyy'),
#  ('wolodimir selenski', 'volodymir zelensky'),
#  ('wolodimir selenski', 'volodymyr zelenski'),
#  ('wolodimir selenski', 'vlodomyr zelensky'),
#  ('wolodimir selenski', 'wolodymyr selenskyj'),
#  ('wolodimir selenski', 'vladimir zelensky'),
#  ('wolodimir selenski', 'wolodimir selenskij'),
#  ('wolodimir selenski', 'volodomyr zelenskiy'),
#  ('wolodimir selenski', 'volodymyr zelenskiy'),
#  ('wolodimir selenski', 'vladimir zelenskyy'),
#  ('wolodimir selenski', 'vladimir aleksandrovich zelensky'),
#  ('wolodimir selenski', 'president volodymyr zelensky'),
#  ('wolodimir selenski', 'zelenskyy'),
#  ('wolodimir selenski', 'volodymyr zelensky'),
#  ('wolodimir selenski', 'volodymyr zelenskyi'),
#  ('wolodimir selenski', 'volodimir zelensky'),
#  ('wolodimir selenski', 'wolodymyr zelenskyj'),
#  ('wolodimir selenski', 'vladimir zelenskiy'),
#  ('wolodimir selenski', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelenskyj', 'volodimir zelenski'),
#  ('volodymyr zelenskyj', 'volodymyr zelenskiyy'),
#  ('volodymyr zelenskyj', 'volodymir zelensky'),
#  ('volodymyr zelenskyj', 'volodymyr zelenski'),
#  ('volodymyr zelenskyj', 'vlodomyr zelensky'),
#  ('volodymyr zelenskyj', 'wolodymyr selenskyj'),
#  ('volodymyr zelenskyj', 'vladimir zelensky'),
#  ('volodymyr zelenskyj', 'wolodimir selenskij'),
#  ('volodymyr zelenskyj', 'volodomyr zelenskiy'),
#  ('volodymyr zelenskyj', 'volodymyr zelenskiy'),
#  ('volodymyr zelenskyj', 'vladimir zelenskyy'),
#  ('volodymyr zelenskyj', 'vladimir aleksandrovich zelensky'),
#  ('volodymyr zelenskyj', 'president volodymyr zelensky'),
#  ('volodymyr zelenskyj', 'zelenskyy'),
#  ('volodymyr zelenskyj', 'volodymyr zelensky'),
#  ('volodymyr zelenskyj', 'volodymyr zelenskyi'),
#  ('volodymyr zelenskyj', 'volodimir zelensky'),
#  ('volodymyr zelenskyj', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenskyj', 'vladimir zelenskiy'),
#  ('volodymyr zelenskyj', 'ukrainian president volodymyr zelensky'),
#  ('volodimir zelenski', 'volodymyr zelenskiyy'),
#  ('volodimir zelenski', 'volodymir zelensky'),
#  ('volodimir zelenski', 'volodymyr zelenski'),
#  ('volodimir zelenski', 'vlodomyr zelensky'),
#  ('volodimir zelenski', 'wolodymyr selenskyj'),
#  ('volodimir zelenski', 'vladimir zelensky'),
#  ('volodimir zelenski', 'wolodimir selenskij'),
#  ('volodimir zelenski', 'volodomyr zelenskiy'),
#  ('volodimir zelenski', 'volodymyr zelenskiy'),
#  ('volodimir zelenski', 'vladimir zelenskyy'),
#  ('volodimir zelenski', 'vladimir aleksandrovich zelensky'),
#  ('volodimir zelenski', 'president volodymyr zelensky'),
#  ('volodimir zelenski', 'zelenskyy'),
#  ('volodimir zelenski', 'volodymyr zelensky'),
#  ('volodimir zelenski', 'volodymyr zelenskyi'),
#  ('volodimir zelenski', 'volodimir zelensky'),
#  ('volodimir zelenski', 'wolodymyr zelenskyj'),
#  ('volodimir zelenski', 'vladimir zelenskiy'),
#  ('volodimir zelenski', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelenskiyy', 'volodymir zelensky'),
#  ('volodymyr zelenskiyy', 'volodymyr zelenski'),
#  ('volodymyr zelenskiyy', 'vlodomyr zelensky'),
#  ('volodymyr zelenskiyy', 'wolodymyr selenskyj'),
#  ('volodymyr zelenskiyy', 'vladimir zelensky'),
#  ('volodymyr zelenskiyy', 'wolodimir selenskij'),
#  ('volodymyr zelenskiyy', 'volodomyr zelenskiy'),
#  ('volodymyr zelenskiyy', 'volodymyr zelenskiy'),
#  ('volodymyr zelenskiyy', 'vladimir zelenskyy'),
#  ('volodymyr zelenskiyy', 'vladimir aleksandrovich zelensky'),
#  ('volodymyr zelenskiyy', 'president volodymyr zelensky'),
#  ('volodymyr zelenskiyy', 'zelenskyy'),
#  ('volodymyr zelenskiyy', 'volodymyr zelensky'),
#  ('volodymyr zelenskiyy', 'volodymyr zelenskyi'),
#  ('volodymyr zelenskiyy', 'volodimir zelensky'),
#  ('volodymyr zelenskiyy', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenskiyy', 'vladimir zelenskiy'),
#  ('volodymyr zelenskiyy', 'ukrainian president volodymyr zelensky'),
#  ('volodymir zelensky', 'volodymyr zelenski'),
#  ('volodymir zelensky', 'vlodomyr zelensky'),
#  ('volodymir zelensky', 'wolodymyr selenskyj'),
#  ('volodymir zelensky', 'vladimir zelensky'),
#  ('volodymir zelensky', 'wolodimir selenskij'),
#  ('volodymir zelensky', 'volodomyr zelenskiy'),
#  ('volodymir zelensky', 'volodymyr zelenskiy'),
#  ('volodymir zelensky', 'vladimir zelenskyy'),
#  ('volodymir zelensky', 'vladimir aleksandrovich zelensky'),
#  ('volodymir zelensky', 'president volodymyr zelensky'),
#  ('volodymir zelensky', 'zelenskyy'),
#  ('volodymir zelensky', 'volodymyr zelensky'),
#  ('volodymir zelensky', 'volodymyr zelenskyi'),
#  ('volodymir zelensky', 'volodimir zelensky'),
#  ('volodymir zelensky', 'wolodymyr zelenskyj'),
#  ('volodymir zelensky', 'vladimir zelenskiy'),
#  ('volodymir zelensky', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelenski', 'vlodomyr zelensky'),
#  ('volodymyr zelenski', 'wolodymyr selenskyj'),
#  ('volodymyr zelenski', 'vladimir zelensky'),
#  ('volodymyr zelenski', 'wolodimir selenskij'),
#  ('volodymyr zelenski', 'volodomyr zelenskiy'),
#  ('volodymyr zelenski', 'volodymyr zelenskiy'),
#  ('volodymyr zelenski', 'vladimir zelenskyy'),
#  ('volodymyr zelenski', 'vladimir aleksandrovich zelensky'),
#  ('volodymyr zelenski', 'president volodymyr zelensky'),
#  ('volodymyr zelenski', 'zelenskyy'),
#  ('volodymyr zelenski', 'volodymyr zelensky'),
#  ('volodymyr zelenski', 'volodymyr zelenskyi'),
#  ('volodymyr zelenski', 'volodimir zelensky'),
#  ('volodymyr zelenski', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenski', 'vladimir zelenskiy'),
#  ('volodymyr zelenski', 'ukrainian president volodymyr zelensky'),
#  ('vlodomyr zelensky', 'wolodymyr selenskyj'),
#  ('vlodomyr zelensky', 'vladimir zelensky'),
#  ('vlodomyr zelensky', 'wolodimir selenskij'),
#  ('vlodomyr zelensky', 'volodomyr zelenskiy'),
#  ('vlodomyr zelensky', 'volodymyr zelenskiy'),
#  ('vlodomyr zelensky', 'vladimir zelenskyy'),
#  ('vlodomyr zelensky', 'vladimir aleksandrovich zelensky'),
#  ('vlodomyr zelensky', 'president volodymyr zelensky'),
#  ('vlodomyr zelensky', 'zelenskyy'),
#  ('vlodomyr zelensky', 'volodymyr zelensky'),
#  ('vlodomyr zelensky', 'volodymyr zelenskyi'),
#  ('vlodomyr zelensky', 'volodimir zelensky'),
#  ('vlodomyr zelensky', 'wolodymyr zelenskyj'),
#  ('vlodomyr zelensky', 'vladimir zelenskiy'),
#  ('vlodomyr zelensky', 'ukrainian president volodymyr zelensky'),
#  ('wolodymyr selenskyj', 'vladimir zelensky'),
#  ('wolodymyr selenskyj', 'wolodimir selenskij'),
#  ('wolodymyr selenskyj', 'volodomyr zelenskiy'),
#  ('wolodymyr selenskyj', 'volodymyr zelenskiy'),
#  ('wolodymyr selenskyj', 'vladimir zelenskyy'),
#  ('wolodymyr selenskyj', 'vladimir aleksandrovich zelensky'),
#  ('wolodymyr selenskyj', 'president volodymyr zelensky'),
#  ('wolodymyr selenskyj', 'zelenskyy'),
#  ('wolodymyr selenskyj', 'volodymyr zelensky'),
#  ('wolodymyr selenskyj', 'volodymyr zelenskyi'),
#  ('wolodymyr selenskyj', 'volodimir zelensky'),
#  ('wolodymyr selenskyj', 'wolodymyr zelenskyj'),
#  ('wolodymyr selenskyj', 'vladimir zelenskiy'),
#  ('wolodymyr selenskyj', 'ukrainian president volodymyr zelensky'),
#  ('vladimir zelensky', 'wolodimir selenskij'),
#  ('vladimir zelensky', 'volodomyr zelenskiy'),
#  ('vladimir zelensky', 'volodymyr zelenskiy'),
#  ('vladimir zelensky', 'vladimir zelenskyy'),
#  ('vladimir zelensky', 'vladimir aleksandrovich zelensky'),
#  ('vladimir zelensky', 'president volodymyr zelensky'),
#  ('vladimir zelensky', 'zelenskyy'),
#  ('vladimir zelensky', 'volodymyr zelensky'),
#  ('vladimir zelensky', 'volodymyr zelenskyi'),
#  ('vladimir zelensky', 'volodimir zelensky'),
#  ('vladimir zelensky', 'wolodymyr zelenskyj'),
#  ('vladimir zelensky', 'vladimir zelenskiy'),
#  ('vladimir zelensky', 'ukrainian president volodymyr zelensky'),
#  ('wolodimir selenskij', 'volodomyr zelenskiy'),
#  ('wolodimir selenskij', 'volodymyr zelenskiy'),
#  ('wolodimir selenskij', 'vladimir zelenskyy'),
#  ('wolodimir selenskij', 'vladimir aleksandrovich zelensky'),
#  ('wolodimir selenskij', 'president volodymyr zelensky'),
#  ('wolodimir selenskij', 'zelenskyy'),
#  ('wolodimir selenskij', 'volodymyr zelensky'),
#  ('wolodimir selenskij', 'volodymyr zelenskyi'),
#  ('wolodimir selenskij', 'volodimir zelensky'),
#  ('wolodimir selenskij', 'wolodymyr zelenskyj'),
#  ('wolodimir selenskij', 'vladimir zelenskiy'),
#  ('wolodimir selenskij', 'ukrainian president volodymyr zelensky'),
#  ('volodomyr zelenskiy', 'volodymyr zelenskiy'),
#  ('volodomyr zelenskiy', 'vladimir zelenskyy'),
#  ('volodomyr zelenskiy', 'vladimir aleksandrovich zelensky'),
#  ('volodomyr zelenskiy', 'president volodymyr zelensky'),
#  ('volodomyr zelenskiy', 'zelenskyy'),
#  ('volodomyr zelenskiy', 'volodymyr zelensky'),
#  ('volodomyr zelenskiy', 'volodymyr zelenskyi'),
#  ('volodomyr zelenskiy', 'volodimir zelensky'),
#  ('volodomyr zelenskiy', 'wolodymyr zelenskyj'),
#  ('volodomyr zelenskiy', 'vladimir zelenskiy'),
#  ('volodomyr zelenskiy', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelenskiy', 'vladimir zelenskyy'),
#  ('volodymyr zelenskiy', 'vladimir aleksandrovich zelensky'),
#  ('volodymyr zelenskiy', 'president volodymyr zelensky'),
#  ('volodymyr zelenskiy', 'zelenskyy'),
#  ('volodymyr zelenskiy', 'volodymyr zelensky'),
#  ('volodymyr zelenskiy', 'volodymyr zelenskyi'),
#  ('volodymyr zelenskiy', 'volodimir zelensky'),
#  ('volodymyr zelenskiy', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenskiy', 'vladimir zelenskiy'),
#  ('volodymyr zelenskiy', 'ukrainian president volodymyr zelensky'),
#  ('vladimir zelenskyy', 'vladimir aleksandrovich zelensky'),
#  ('vladimir zelenskyy', 'president volodymyr zelensky'),
#  ('vladimir zelenskyy', 'zelenskyy'),
#  ('vladimir zelenskyy', 'volodymyr zelensky'),
#  ('vladimir zelenskyy', 'volodymyr zelenskyi'),
#  ('vladimir zelenskyy', 'volodimir zelensky'),
#  ('vladimir zelenskyy', 'wolodymyr zelenskyj'),
#  ('vladimir zelenskyy', 'vladimir zelenskiy'),
#  ('vladimir zelenskyy', 'ukrainian president volodymyr zelensky'),
#  ('vladimir aleksandrovich zelensky', 'president volodymyr zelensky'),
#  ('vladimir aleksandrovich zelensky', 'zelenskyy'),
#  ('vladimir aleksandrovich zelensky', 'volodymyr zelensky'),
#  ('vladimir aleksandrovich zelensky', 'volodymyr zelenskyi'),
#  ('vladimir aleksandrovich zelensky', 'volodimir zelensky'),
#  ('vladimir aleksandrovich zelensky', 'wolodymyr zelenskyj'),
#  ('vladimir aleksandrovich zelensky', 'vladimir zelenskiy'),
#  ('vladimir aleksandrovich zelensky',
#   'ukrainian president volodymyr zelensky'),
#  ('president volodymyr zelensky', 'zelenskyy'),
#  ('president volodymyr zelensky', 'volodymyr zelensky'),
#  ('president volodymyr zelensky', 'volodymyr zelenskyi'),
#  ('president volodymyr zelensky', 'volodimir zelensky'),
#  ('president volodymyr zelensky', 'wolodymyr zelenskyj'),
#  ('president volodymyr zelensky', 'vladimir zelenskiy'),
#  ('president volodymyr zelensky', 'ukrainian president volodymyr zelensky'),
#  ('zelenskyy', 'volodymyr zelensky'),
#  ('zelenskyy', 'volodymyr zelenskyi'),
#  ('zelenskyy', 'volodimir zelensky'),
#  ('zelenskyy', 'wolodymyr zelenskyj'),
#  ('zelenskyy', 'vladimir zelenskiy'),
#  ('zelenskyy', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelensky', 'volodymyr zelenskyi'),
#  ('volodymyr zelensky', 'volodimir zelensky'),
#  ('volodymyr zelensky', 'wolodymyr zelenskyj'),
#  ('volodymyr zelensky', 'vladimir zelenskiy'),
#  ('volodymyr zelensky', 'ukrainian president volodymyr zelensky'),
#  ('volodymyr zelenskyi', 'volodimir zelensky'),
#  ('volodymyr zelenskyi', 'wolodymyr zelenskyj'),
#  ('volodymyr zelenskyi', 'vladimir zelenskiy'),
#  ('volodymyr zelenskyi', 'ukrainian president volodymyr zelensky'),
#  ('volodimir zelensky', 'wolodymyr zelenskyj'),
#  ('volodimir zelensky', 'vladimir zelenskiy'),
#  ('volodimir zelensky', 'ukrainian president volodymyr zelensky'),
#  ('wolodymyr zelenskyj', 'vladimir zelenskiy'),
#  ('wolodymyr zelenskyj', 'ukrainian president volodymyr zelensky'),
#  ('vladimir zelenskiy', 'ukrainian president volodymyr zelensky'),
#  ('ukrainian resistance center', 'ukrainian national resistance center'),
#  ('ukrainian resistance center', 'ukrainian center for national resistance'),
#  ('ukrainian resistance center', 'national resistance center of ukraine'),
#  ('ukrainian resistance center', 'ukrainian center of national resistance'),
#  ('ukrainian resistance center', "ukraine's national resistance center"),
#  ('ukrainian resistance center', 'ukrainian centre of national resistance'),
#  ('ukrainian resistance center', "ukraine's national resistance centre"),
#  ('ukrainian resistance center', 'center of national resistance of ukraine'),
#  ('ukrainian resistance center', 'centre of national resistance of ukraine'),
#  ('ukrainian resistance center',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('ukrainian resistance center', 'ukrainian resistance'),
#  ('ukrainian resistance center', "centre national de la résistance d'ukraine"),
#  ('ukrainian resistance center',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian resistance center', 'ukrainian center for national opposition'),
#  ('ukrainian resistance center',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian resistance center', 'pro-ukrainian resistance group'),
#  ('ukrainian resistance center',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian national resistance center',
#   'ukrainian center for national resistance'),
#  ('ukrainian national resistance center',
#   'national resistance center of ukraine'),
#  ('ukrainian national resistance center',
#   'ukrainian center of national resistance'),
#  ('ukrainian national resistance center',
#   "ukraine's national resistance center"),
#  ('ukrainian national resistance center',
#   'ukrainian centre of national resistance'),
#  ('ukrainian national resistance center',
#   "ukraine's national resistance centre"),
#  ('ukrainian national resistance center',
#   'center of national resistance of ukraine'),
#  ('ukrainian national resistance center',
#   'centre of national resistance of ukraine'),
#  ('ukrainian national resistance center',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('ukrainian national resistance center', 'ukrainian resistance'),
#  ('ukrainian national resistance center',
#   "centre national de la résistance d'ukraine"),
#  ('ukrainian national resistance center',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian national resistance center',
#   'ukrainian center for national opposition'),
#  ('ukrainian national resistance center',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian national resistance center', 'pro-ukrainian resistance group'),
#  ('ukrainian national resistance center',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian center for national resistance',
#   'national resistance center of ukraine'),
#  ('ukrainian center for national resistance',
#   'ukrainian center of national resistance'),
#  ('ukrainian center for national resistance',
#   "ukraine's national resistance center"),
#  ('ukrainian center for national resistance',
#   'ukrainian centre of national resistance'),
#  ('ukrainian center for national resistance',
#   "ukraine's national resistance centre"),
#  ('ukrainian center for national resistance',
#   'center of national resistance of ukraine'),
#  ('ukrainian center for national resistance',
#   'centre of national resistance of ukraine'),
#  ('ukrainian center for national resistance',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('ukrainian center for national resistance', 'ukrainian resistance'),
#  ('ukrainian center for national resistance',
#   "centre national de la résistance d'ukraine"),
#  ('ukrainian center for national resistance',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian center for national resistance',
#   'ukrainian center for national opposition'),
#  ('ukrainian center for national resistance',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian center for national resistance',
#   'pro-ukrainian resistance group'),
#  ('ukrainian center for national resistance',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('national resistance center of ukraine',
#   'ukrainian center of national resistance'),
#  ('national resistance center of ukraine',
#   "ukraine's national resistance center"),
#  ('national resistance center of ukraine',
#   'ukrainian centre of national resistance'),
#  ('national resistance center of ukraine',
#   "ukraine's national resistance centre"),
#  ('national resistance center of ukraine',
#   'center of national resistance of ukraine'),
#  ('national resistance center of ukraine',
#   'centre of national resistance of ukraine'),
#  ('national resistance center of ukraine',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('national resistance center of ukraine', 'ukrainian resistance'),
#  ('national resistance center of ukraine',
#   "centre national de la résistance d'ukraine"),
#  ('national resistance center of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('national resistance center of ukraine',
#   'ukrainian center for national opposition'),
#  ('national resistance center of ukraine',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('national resistance center of ukraine', 'pro-ukrainian resistance group'),
#  ('national resistance center of ukraine',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian center of national resistance',
#   "ukraine's national resistance center"),
#  ('ukrainian center of national resistance',
#   'ukrainian centre of national resistance'),
#  ('ukrainian center of national resistance',
#   "ukraine's national resistance centre"),
#  ('ukrainian center of national resistance',
#   'center of national resistance of ukraine'),
#  ('ukrainian center of national resistance',
#   'centre of national resistance of ukraine'),
#  ('ukrainian center of national resistance',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('ukrainian center of national resistance', 'ukrainian resistance'),
#  ('ukrainian center of national resistance',
#   "centre national de la résistance d'ukraine"),
#  ('ukrainian center of national resistance',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian center of national resistance',
#   'ukrainian center for national opposition'),
#  ('ukrainian center of national resistance',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian center of national resistance', 'pro-ukrainian resistance group'),
#  ('ukrainian center of national resistance',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ("ukraine's national resistance center",
#   'ukrainian centre of national resistance'),
#  ("ukraine's national resistance center",
#   "ukraine's national resistance centre"),
#  ("ukraine's national resistance center",
#   'center of national resistance of ukraine'),
#  ("ukraine's national resistance center",
#   'centre of national resistance of ukraine'),
#  ("ukraine's national resistance center",
#   'centre of national resistance of the armed forces of ukraine'),
#  ("ukraine's national resistance center", 'ukrainian resistance'),
#  ("ukraine's national resistance center",
#   "centre national de la résistance d'ukraine"),
#  ("ukraine's national resistance center",
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ("ukraine's national resistance center",
#   'ukrainian center for national opposition'),
#  ("ukraine's national resistance center",
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ("ukraine's national resistance center", 'pro-ukrainian resistance group'),
#  ("ukraine's national resistance center",
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian centre of national resistance',
#   "ukraine's national resistance centre"),
#  ('ukrainian centre of national resistance',
#   'center of national resistance of ukraine'),
#  ('ukrainian centre of national resistance',
#   'centre of national resistance of ukraine'),
#  ('ukrainian centre of national resistance',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('ukrainian centre of national resistance', 'ukrainian resistance'),
#  ('ukrainian centre of national resistance',
#   "centre national de la résistance d'ukraine"),
#  ('ukrainian centre of national resistance',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian centre of national resistance',
#   'ukrainian center for national opposition'),
#  ('ukrainian centre of national resistance',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian centre of national resistance', 'pro-ukrainian resistance group'),
#  ('ukrainian centre of national resistance',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ("ukraine's national resistance centre",
#   'center of national resistance of ukraine'),
#  ("ukraine's national resistance centre",
#   'centre of national resistance of ukraine'),
#  ("ukraine's national resistance centre",
#   'centre of national resistance of the armed forces of ukraine'),
#  ("ukraine's national resistance centre", 'ukrainian resistance'),
#  ("ukraine's national resistance centre",
#   "centre national de la résistance d'ukraine"),
#  ("ukraine's national resistance centre",
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ("ukraine's national resistance centre",
#   'ukrainian center for national opposition'),
#  ("ukraine's national resistance centre",
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ("ukraine's national resistance centre", 'pro-ukrainian resistance group'),
#  ("ukraine's national resistance centre",
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('center of national resistance of ukraine',
#   'centre of national resistance of ukraine'),
#  ('center of national resistance of ukraine',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('center of national resistance of ukraine', 'ukrainian resistance'),
#  ('center of national resistance of ukraine',
#   "centre national de la résistance d'ukraine"),
#  ('center of national resistance of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('center of national resistance of ukraine',
#   'ukrainian center for national opposition'),
#  ('center of national resistance of ukraine',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('center of national resistance of ukraine',
#   'pro-ukrainian resistance group'),
#  ('center of national resistance of ukraine',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('centre of national resistance of ukraine',
#   'centre of national resistance of the armed forces of ukraine'),
#  ('centre of national resistance of ukraine', 'ukrainian resistance'),
#  ('centre of national resistance of ukraine',
#   "centre national de la résistance d'ukraine"),
#  ('centre of national resistance of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('centre of national resistance of ukraine',
#   'ukrainian center for national opposition'),
#  ('centre of national resistance of ukraine',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('centre of national resistance of ukraine',
#   'pro-ukrainian resistance group'),
#  ('centre of national resistance of ukraine',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian resistance'),
#  ('centre of national resistance of the armed forces of ukraine',
#   "centre national de la résistance d'ukraine"),
#  ('centre of national resistance of the armed forces of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian center for national opposition'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'pro-ukrainian resistance group'),
#  ('centre of national resistance of the armed forces of ukraine',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian resistance', "centre national de la résistance d'ukraine"),
#  ('ukrainian resistance',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('ukrainian resistance', 'ukrainian center for national opposition'),
#  ('ukrainian resistance',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian resistance', 'pro-ukrainian resistance group'),
#  ('ukrainian resistance',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ("centre national de la résistance d'ukraine",
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ("centre national de la résistance d'ukraine",
#   'ukrainian center for national opposition'),
#  ("centre national de la résistance d'ukraine",
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ("centre national de la résistance d'ukraine",
#   'pro-ukrainian resistance group'),
#  ("centre national de la résistance d'ukraine",
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian center for national opposition'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'pro-ukrainian resistance group'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('ukrainian center for national opposition',
#   'national resistance center of the special operations forces of the armed forces of ukraine'),
#  ('ukrainian center for national opposition',
#   'pro-ukrainian resistance group'),
#  ('ukrainian center for national opposition',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'pro-ukrainian resistance group'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('pro-ukrainian resistance group',
#   "national resistance center of the special operations forces of ukraine's armed forces"),
#  ('u.k. defense ministry', 'ministry of defence of the united kingdom'),
#  ('u.k. defense ministry', 'uk ministry of defence'),
#  ('u.k. defense ministry', 'uk defense ministry'),
#  ('u.k. defense ministry', "britain's defense ministry"),
#  ('u.k. defense ministry', 'british ministry of defence'),
#  ('u.k. defense ministry', "britain's defence ministry"),
#  ('u.k. defense ministry', "united kingdom's ministry of defence"),
#  ('u.k. defense ministry', 'ministry of defence'),
#  ('u.k. defense ministry', 'united kingdom ministry of defence'),
#  ('u.k. defense ministry', "united kingdom's ministry of defense"),
#  ('u.k. defense ministry', 'british ministry of defense'),
#  ('u.k. defense ministry', 'ministry of defense of the united kingdom'),
#  ('u.k. defense ministry', 'uk ministry of defense'),
#  ('u.k. defense ministry', 'uk defence ministry'),
#  ('u.k. defense ministry', "uk's ministry of defence"),
#  ('u.k. defense ministry', 'british defense ministry'),
#  ('ministry of defence of the united kingdom', 'uk ministry of defence'),
#  ('ministry of defence of the united kingdom', 'uk defense ministry'),
#  ('ministry of defence of the united kingdom', "britain's defense ministry"),
#  ('ministry of defence of the united kingdom', 'british ministry of defence'),
#  ('ministry of defence of the united kingdom', "britain's defence ministry"),
#  ('ministry of defence of the united kingdom',
#   "united kingdom's ministry of defence"),
#  ('ministry of defence of the united kingdom', 'ministry of defence'),
#  ('ministry of defence of the united kingdom',
#   'united kingdom ministry of defence'),
#  ('ministry of defence of the united kingdom',
#   "united kingdom's ministry of defense"),
#  ('ministry of defence of the united kingdom', 'british ministry of defense'),
#  ('ministry of defence of the united kingdom',
#   'ministry of defense of the united kingdom'),
#  ('ministry of defence of the united kingdom', 'uk ministry of defense'),
#  ('ministry of defence of the united kingdom', 'uk defence ministry'),
#  ('ministry of defence of the united kingdom', "uk's ministry of defence"),
#  ('ministry of defence of the united kingdom', 'british defense ministry'),
#  ('uk ministry of defence', 'uk defense ministry'),
#  ('uk ministry of defence', "britain's defense ministry"),
#  ('uk ministry of defence', 'british ministry of defence'),
#  ('uk ministry of defence', "britain's defence ministry"),
#  ('uk ministry of defence', "united kingdom's ministry of defence"),
#  ('uk ministry of defence', 'ministry of defence'),
#  ('uk ministry of defence', 'united kingdom ministry of defence'),
#  ('uk ministry of defence', "united kingdom's ministry of defense"),
#  ('uk ministry of defence', 'british ministry of defense'),
#  ('uk ministry of defence', 'ministry of defense of the united kingdom'),
#  ('uk ministry of defence', 'uk ministry of defense'),
#  ('uk ministry of defence', 'uk defence ministry'),
#  ('uk ministry of defence', "uk's ministry of defence"),
# ...
#  ('uk defence ministry', 'british defense ministry'),
#  ("uk's ministry of defence", 'british defense ministry'),
#  ('ukrainian defence forces', 'ukrainian forces'),
#  ('ukrainian defence forces', "ukraine's armed forces"),
#  ('ukrainian defence forces', "ukraine's defense forces"),
#  ('ukrainian defence forces', 'forces armées ukrainiennes'),
#  ('ukrainian defence forces', 'ukrainian defense forces'),
#  ('ukrainian defence forces', 'ukrainian military'),
#  ('ukrainian defence forces', 'ukrainian troops'),
#  ('ukrainian defence forces', 'defense forces of ukraine'),
#  ('ukrainian defence forces', 'armed forces of ukraine'),
#  ('ukrainian defence forces', "ukraine's military"),
#  ('ukrainian defence forces', 'ukrainian armed forces'),
#  ('ukrainian defence forces', 'ukraine military'),
#  ('ukrainian defence forces', 'ukrainian military officials'),
#  ('ukrainian defence forces', 'ukrainian army'),
#  ('ukrainian forces', "ukraine's armed forces"),
#  ('ukrainian forces', "ukraine's defense forces"),
#  ('ukrainian forces', 'forces armées ukrainiennes'),
#  ('ukrainian forces', 'ukrainian defense forces'),
#  ('ukrainian forces', 'ukrainian military'),
#  ('ukrainian forces', 'ukrainian troops'),
#  ('ukrainian forces', 'defense forces of ukraine'),
#  ('ukrainian forces', 'armed forces of ukraine'),
#  ('ukrainian forces', "ukraine's military"),
#  ('ukrainian forces', 'ukrainian armed forces'),
#  ('ukrainian forces', 'ukraine military'),
#  ('ukrainian forces', 'ukrainian military officials'),
#  ('ukrainian forces', 'ukrainian army'),
#  ("ukraine's armed forces", "ukraine's defense forces"),
#  ("ukraine's armed forces", 'forces armées ukrainiennes'),
#  ("ukraine's armed forces", 'ukrainian defense forces'),
#  ("ukraine's armed forces", 'ukrainian military'),
#  ("ukraine's armed forces", 'ukrainian troops'),
#  ("ukraine's armed forces", 'defense forces of ukraine'),
#  ("ukraine's armed forces", 'armed forces of ukraine'),
#  ("ukraine's armed forces", "ukraine's military"),
#  ("ukraine's armed forces", 'ukrainian armed forces'),
#  ("ukraine's armed forces", 'ukraine military'),
#  ("ukraine's armed forces", 'ukrainian military officials'),
#  ("ukraine's armed forces", 'ukrainian army'),
#  ("ukraine's defense forces", 'forces armées ukrainiennes'),
#  ("ukraine's defense forces", 'ukrainian defense forces'),
#  ("ukraine's defense forces", 'ukrainian military'),
#  ("ukraine's defense forces", 'ukrainian troops'),
#  ("ukraine's defense forces", 'defense forces of ukraine'),
#  ("ukraine's defense forces", 'armed forces of ukraine'),
#  ("ukraine's defense forces", "ukraine's military"),
#  ("ukraine's defense forces", 'ukrainian armed forces'),
#  ("ukraine's defense forces", 'ukraine military'),
#  ("ukraine's defense forces", 'ukrainian military officials'),
#  ("ukraine's defense forces", 'ukrainian army'),
#  ('forces armées ukrainiennes', 'ukrainian defense forces'),
#  ('forces armées ukrainiennes', 'ukrainian military'),
#  ('forces armées ukrainiennes', 'ukrainian troops'),
#  ('forces armées ukrainiennes', 'defense forces of ukraine'),
#  ('forces armées ukrainiennes', 'armed forces of ukraine'),
#  ('forces armées ukrainiennes', "ukraine's military"),
#  ('forces armées ukrainiennes', 'ukrainian armed forces'),
#  ('forces armées ukrainiennes', 'ukraine military'),
#  ('forces armées ukrainiennes', 'ukrainian military officials'),
#  ('forces armées ukrainiennes', 'ukrainian army'),
#  ('ukrainian defense forces', 'ukrainian military'),
#  ('ukrainian defense forces', 'ukrainian troops'),
#  ('ukrainian defense forces', 'defense forces of ukraine'),
#  ('ukrainian defense forces', 'armed forces of ukraine'),
#  ('ukrainian defense forces', "ukraine's military"),
#  ('ukrainian defense forces', 'ukrainian armed forces'),
#  ('ukrainian defense forces', 'ukraine military'),
#  ('ukrainian defense forces', 'ukrainian military officials'),
#  ('ukrainian defense forces', 'ukrainian army'),
#  ('ukrainian military', 'ukrainian troops'),
#  ('ukrainian military', 'defense forces of ukraine'),
#  ('ukrainian military', 'armed forces of ukraine'),
#  ('ukrainian military', "ukraine's military"),
#  ('ukrainian military', 'ukrainian armed forces'),
#  ('ukrainian military', 'ukraine military'),
#  ('ukrainian military', 'ukrainian military officials'),
#  ('ukrainian military', 'ukrainian army'),
#  ('ukrainian troops', 'defense forces of ukraine'),
#  ('ukrainian troops', 'armed forces of ukraine'),
#  ('ukrainian troops', "ukraine's military"),
#  ('ukrainian troops', 'ukrainian armed forces'),
#  ('ukrainian troops', 'ukraine military'),
#  ('ukrainian troops', 'ukrainian military officials'),
#  ('ukrainian troops', 'ukrainian army'),
#  ('defense forces of ukraine', 'armed forces of ukraine'),
#  ('defense forces of ukraine', "ukraine's military"),
#  ('defense forces of ukraine', 'ukrainian armed forces'),
#  ('defense forces of ukraine', 'ukraine military'),
#  ('defense forces of ukraine', 'ukrainian military officials'),
#  ('defense forces of ukraine', 'ukrainian army'),
#  ('armed forces of ukraine', "ukraine's military"),
#  ('armed forces of ukraine', 'ukrainian armed forces'),
#  ('armed forces of ukraine', 'ukraine military'),
#  ('armed forces of ukraine', 'ukrainian military officials'),
#  ('armed forces of ukraine', 'ukrainian army'),
#  ("ukraine's military", 'ukrainian armed forces'),
#  ("ukraine's military", 'ukraine military'),
#  ("ukraine's military", 'ukrainian military officials'),
#  ("ukraine's military", 'ukrainian army'),
#  ('ukrainian armed forces', 'ukraine military'),
#  ('ukrainian armed forces', 'ukrainian military officials'),
#  ('ukrainian armed forces', 'ukrainian army'),
#  ('ukraine military', 'ukrainian military officials'),
#  ('ukraine military', 'ukrainian army'),
#  ('ukrainian military officials', 'ukrainian army'),
#  ('ministry of defence of the russian federation',
#   'russian ministry of defense'),
#  ('ministry of defence of the russian federation',
#   "russia's ministry of defence"),
#  ('ministry of defence of the russian federation',
#   'russian ministry of defence'),
#  ('ministry of defence of the russian federation', 'russian mod'),
#  ('ministry of defence of the russian federation',
#   'ministry of defence of russia'),
#  ('ministry of defence of the russian federation',
#   'ministry of defense of russia'),
#  ('ministry of defence of the russian federation', 'russian defense ministry'),
#  ('ministry of defence of the russian federation',
#   'ministry of defense of the russian federation'),
#  ('ministry of defence of the russian federation',
#   "russia's defence ministry"),
#  ('ministry of defence of the russian federation',
#   "russia's defense ministry"),
#  ('ministry of defence of the russian federation', 'russian defence ministry'),
#  ('russian ministry of defense', "russia's ministry of defence"),
#  ('russian ministry of defense', 'russian ministry of defence'),
#  ('russian ministry of defense', 'russian mod'),
#  ('russian ministry of defense', 'ministry of defence of russia'),
#  ('russian ministry of defense', 'ministry of defense of russia'),
#  ('russian ministry of defense', 'russian defense ministry'),
#  ('russian ministry of defense',
#   'ministry of defense of the russian federation'),
#  ('russian ministry of defense', "russia's defence ministry"),
#  ('russian ministry of defense', "russia's defense ministry"),
#  ('russian ministry of defense', 'russian defence ministry'),
#  ("russia's ministry of defence", 'russian ministry of defence'),
#  ("russia's ministry of defence", 'russian mod'),
#  ("russia's ministry of defence", 'ministry of defence of russia'),
#  ("russia's ministry of defence", 'ministry of defense of russia'),
#  ("russia's ministry of defence", 'russian defense ministry'),
#  ("russia's ministry of defence",
#   'ministry of defense of the russian federation'),
#  ("russia's ministry of defence", "russia's defence ministry"),
#  ("russia's ministry of defence", "russia's defense ministry"),
#  ("russia's ministry of defence", 'russian defence ministry'),
#  ('russian ministry of defence', 'russian mod'),
#  ('russian ministry of defence', 'ministry of defence of russia'),
#  ('russian ministry of defence', 'ministry of defense of russia'),
#  ('russian ministry of defence', 'russian defense ministry'),
#  ('russian ministry of defence',
#   'ministry of defense of the russian federation'),
#  ('russian ministry of defence', "russia's defence ministry"),
#  ('russian ministry of defence', "russia's defense ministry"),
#  ('russian ministry of defence', 'russian defence ministry'),
#  ('russian mod', 'ministry of defence of russia'),
#  ('russian mod', 'ministry of defense of russia'),
#  ('russian mod', 'russian defense ministry'),
#  ('russian mod', 'ministry of defense of the russian federation'),
#  ('russian mod', "russia's defence ministry"),
#  ('russian mod', "russia's defense ministry"),
#  ('russian mod', 'russian defence ministry'),
#  ('ministry of defence of russia', 'ministry of defense of russia'),
#  ('ministry of defence of russia', 'russian defense ministry'),
#  ('ministry of defence of russia',
#   'ministry of defense of the russian federation'),
#  ('ministry of defence of russia', "russia's defence ministry"),
#  ('ministry of defence of russia', "russia's defense ministry"),
#  ('ministry of defence of russia', 'russian defence ministry'),
#  ('ministry of defense of russia', 'russian defense ministry'),
#  ('ministry of defense of russia',
#   'ministry of defense of the russian federation'),
#  ('ministry of defense of russia', "russia's defence ministry"),
#  ('ministry of defense of russia', "russia's defense ministry"),
#  ('ministry of defense of russia', 'russian defence ministry'),
#  ('russian defense ministry', 'ministry of defense of the russian federation'),
#  ('russian defense ministry', "russia's defence ministry"),
#  ('russian defense ministry', "russia's defense ministry"),
#  ('russian defense ministry', 'russian defence ministry'),
#  ('ministry of defense of the russian federation',
#   "russia's defence ministry"),
#  ('ministry of defense of the russian federation',
#   "russia's defense ministry"),
#  ('ministry of defense of the russian federation', 'russian defence ministry'),
#  ("russia's defence ministry", "russia's defense ministry"),
#  ("russia's defence ministry", 'russian defence ministry'),
#  ("russia's defense ministry", 'russian defence ministry'),
#  ('ministry of foreign affairs of ukraine',
#   "ukraine's ministry of foreign affairs"),
#  ('ministry of foreign affairs of ukraine',
#   "ukraine's foreign affairs ministry"),
#  ('ministry of foreign affairs of ukraine', 'ukrainian foreign ministry'),
#  ('ministry of foreign affairs of ukraine', 'ukrainian foreign minister'),
#  ('ministry of foreign affairs of ukraine', "ukraine's foreign ministry"),
#  ('ministry of foreign affairs of ukraine',
#   'ministère ukrainien des affaires étrangères'),
#  ('ministry of foreign affairs of ukraine',
#   'ukrainian ministry of foreign affairs'),
#  ('ministry of foreign affairs of ukraine', 'ukraine foreign ministry'),
#  ('ministry of foreign affairs of ukraine', 'ukrainian ministry'),
#  ('ministry of foreign affairs of ukraine',
#   'ukrainian foreign affairs ministry'),
#  ("ukraine's ministry of foreign affairs",
#   "ukraine's foreign affairs ministry"),
#  ("ukraine's ministry of foreign affairs", 'ukrainian foreign ministry'),
#  ("ukraine's ministry of foreign affairs", 'ukrainian foreign minister'),
#  ("ukraine's ministry of foreign affairs", "ukraine's foreign ministry"),
#  ("ukraine's ministry of foreign affairs",
#   'ministère ukrainien des affaires étrangères'),
#  ("ukraine's ministry of foreign affairs",
#   'ukrainian ministry of foreign affairs'),
#  ("ukraine's ministry of foreign affairs", 'ukraine foreign ministry'),
#  ("ukraine's ministry of foreign affairs", 'ukrainian ministry'),
#  ("ukraine's ministry of foreign affairs",
#   'ukrainian foreign affairs ministry'),
#  ("ukraine's foreign affairs ministry", 'ukrainian foreign ministry'),
#  ("ukraine's foreign affairs ministry", 'ukrainian foreign minister'),
#  ("ukraine's foreign affairs ministry", "ukraine's foreign ministry"),
#  ("ukraine's foreign affairs ministry",
#   'ministère ukrainien des affaires étrangères'),
#  ("ukraine's foreign affairs ministry",
#   'ukrainian ministry of foreign affairs'),
#  ("ukraine's foreign affairs ministry", 'ukraine foreign ministry'),
#  ("ukraine's foreign affairs ministry", 'ukrainian ministry'),
#  ("ukraine's foreign affairs ministry", 'ukrainian foreign affairs ministry'),
#  ('ukrainian foreign ministry', 'ukrainian foreign minister'),
#  ('ukrainian foreign ministry', "ukraine's foreign ministry"),
#  ('ukrainian foreign ministry', 'ministère ukrainien des affaires étrangères'),
#  ('ukrainian foreign ministry', 'ukrainian ministry of foreign affairs'),
#  ('ukrainian foreign ministry', 'ukraine foreign ministry'),
#  ('ukrainian foreign ministry', 'ukrainian ministry'),
#  ('ukrainian foreign ministry', 'ukrainian foreign affairs ministry'),
#  ('ukrainian foreign minister', "ukraine's foreign ministry"),
#  ('ukrainian foreign minister', 'ministère ukrainien des affaires étrangères'),
#  ('ukrainian foreign minister', 'ukrainian ministry of foreign affairs'),
#  ('ukrainian foreign minister', 'ukraine foreign ministry'),
#  ('ukrainian foreign minister', 'ukrainian ministry'),
#  ('ukrainian foreign minister', 'ukrainian foreign affairs ministry'),
#  ("ukraine's foreign ministry", 'ministère ukrainien des affaires étrangères'),
#  ("ukraine's foreign ministry", 'ukrainian ministry of foreign affairs'),
#  ("ukraine's foreign ministry", 'ukraine foreign ministry'),
#  ("ukraine's foreign ministry", 'ukrainian ministry'),
#  ("ukraine's foreign ministry", 'ukrainian foreign affairs ministry'),
#  ('ministère ukrainien des affaires étrangères',
#   'ukrainian ministry of foreign affairs'),
#  ('ministère ukrainien des affaires étrangères', 'ukraine foreign ministry'),
#  ('ministère ukrainien des affaires étrangères', 'ukrainian ministry'),
#  ('ministère ukrainien des affaires étrangères',
#   'ukrainian foreign affairs ministry'),
#  ('ukrainian ministry of foreign affairs', 'ukraine foreign ministry'),
#  ('ukrainian ministry of foreign affairs', 'ukrainian ministry'),
#  ('ukrainian ministry of foreign affairs',
#   'ukrainian foreign affairs ministry'),
#  ('ukraine foreign ministry', 'ukrainian ministry'),
#  ('ukraine foreign ministry', 'ukrainian foreign affairs ministry'),
#  ('ukrainian ministry', 'ukrainian foreign affairs ministry'),
#  ('mykhailo podoliak', 'mykhailo podolyak'),
#  ('mykhailo podoliak', 'mykhalio podlyak'),
#  ('mykhailo podoliak', 'mykhaylo podolyak'),
#  ('mykhailo podoliak', 'mikhailo podoliak'),
#  ('mykhailo podoliak', 'mikhaïlo podoliak'),
#  ('mykhailo podoliak', 'mikhail podoliak'),
#  ('mykhailo podoliak', 'mykola podolsky'),
#  ('mykhailo podoliak', 'mikhailo podolyak'),
#  ('mykhailo podoliak', 'mijailo podoliak'),
#  ('mykhailo podoliak', 'miikhail podoliak'),
#  ('mykhailo podolyak', 'mykhalio podlyak'),
#  ('mykhailo podolyak', 'mykhaylo podolyak'),
#  ('mykhailo podolyak', 'mikhailo podoliak'),
#  ('mykhailo podolyak', 'mikhaïlo podoliak'),
#  ('mykhailo podolyak', 'mikhail podoliak'),
#  ('mykhailo podolyak', 'mykola podolsky'),
#  ('mykhailo podolyak', 'mikhailo podolyak'),
#  ('mykhailo podolyak', 'mijailo podoliak'),
#  ('mykhailo podolyak', 'miikhail podoliak'),
#  ('mykhalio podlyak', 'mykhaylo podolyak'),
#  ('mykhalio podlyak', 'mikhailo podoliak'),
#  ('mykhalio podlyak', 'mikhaïlo podoliak'),
#  ('mykhalio podlyak', 'mikhail podoliak'),
#  ('mykhalio podlyak', 'mykola podolsky'),
#  ('mykhalio podlyak', 'mikhailo podolyak'),
#  ('mykhalio podlyak', 'mijailo podoliak'),
#  ('mykhalio podlyak', 'miikhail podoliak'),
#  ('mykhaylo podolyak', 'mikhailo podoliak'),
#  ('mykhaylo podolyak', 'mikhaïlo podoliak'),
#  ('mykhaylo podolyak', 'mikhail podoliak'),
#  ('mykhaylo podolyak', 'mykola podolsky'),
#  ('mykhaylo podolyak', 'mikhailo podolyak'),
#  ('mykhaylo podolyak', 'mijailo podoliak'),
#  ('mykhaylo podolyak', 'miikhail podoliak'),
#  ('mikhailo podoliak', 'mikhaïlo podoliak'),
#  ('mikhailo podoliak', 'mikhail podoliak'),
#  ('mikhailo podoliak', 'mykola podolsky'),
#  ('mikhailo podoliak', 'mikhailo podolyak'),
#  ('mikhailo podoliak', 'mijailo podoliak'),
#  ...]

# %%
positive_samples_set = set(positive_samples)
negative_samples_set = set(negative_samples)

# %%
# Convert the samples to sorted tuples (to handle unordered pairs)
positive_samples_set = {tuple(sorted(sample)) for sample in positive_samples}
negative_samples_set = {tuple(sorted(sample)) for sample in negative_samples}

# Calculate true positives (TP): positive samples that exist in positive_results
true_positives_results = [sample for sample in positive_samples_set if tuple(sorted(sample)) in positive_results]

# Calculate false negatives (FN): positive samples that do not exist in positive_results
false_negatives_results = [sample for sample in positive_samples_set if tuple(sorted(sample)) not in positive_results]

# Calculate false positives (FP): negative samples that exist in positive_results
false_positives_results = [sample for sample in negative_samples_set if tuple(sorted(sample)) in positive_results]

# Calculate true negatives (TN): negative samples that do not exist in positive_results
true_negatives_results = [sample for sample in negative_samples_set if tuple(sorted(sample)) not in positive_results]


true_positives = len(true_positives_results)
false_negatives = len(false_negatives_results)
false_positives = len(false_positives_results)
true_negatives = len(true_negatives_results)

# Output the results
print("True Positives (TP):", true_positives)
print("False Negatives (FN):", false_negatives)
print("False Positives (FP):", false_positives)
print("True Negatives (TN):", true_negatives)
# Out:
# True Positives (TP): 146
# False Negatives (FN): 252
# False Positives (FP): 8
# True Negatives (TN): 41518

# %%
# Calculate the metrics based on TP, FP, TN, FN
precision = true_positives / (true_positives + false_positives) if (true_positives + false_positives) != 0 else 0
recall = true_positives / (true_positives + false_negatives) if (true_positives + false_negatives) != 0 else 0
f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) != 0 else 0
accuracy = (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)
fpr = false_positives / (false_positives + true_negatives) if (false_positives + true_negatives) != 0 else 0
specificity = true_negatives / (true_negatives + false_positives) if (true_negatives + false_positives) != 0 else 0

# Output the results
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1_score:.4f}")
print(f"Accuracy: {accuracy:.4f}")
print(f"False Positive Rate (FPR): {fpr:.4f}")
print(f"Specificity: {specificity:.4f}")
# Out:
# Precision: 0.9481
# Recall: 0.3668
# F1 Score: 0.5290
# Accuracy: 0.9938
# False Positive Rate (FPR): 0.0002
# Specificity: 0.9998

# %%
false_positives_results
# Out:
# [("ukraine's defense forces", "ukraine's military"),
#  ("ukraine's defense forces", 'ukrainian troops'),
#  ('abbas galljamov', 'abbas galyamov'),
#  ("ukraine's defense forces", 'ukrainian army'),
#  ("ukraine's defense forces", 'ukrainian defense forces'),
#  ("ukraine's defense forces", 'ukrainian military'),
#  ("ukraine's armed forces", "ukraine's defense forces"),
#  ("ukraine's defense forces", 'ukrainian armed forces')]

# %%
false_negatives_results
# Out:
# [("ukraine's military", 'ukrainian troops'),
#  ("russia's defense ministry", 'russian defense ministry'),
#  ("ukraine's military", 'ukrainian defence forces'),
#  ('centre of national resistance of ukraine',
#   "ukraine's national resistance center"),
#  ('ukraine military', 'ukrainian troops'),
#  ('ukrainian defense forces', 'ukrainian forces'),
#  ("ukraine's defense forces", 'ukrainian defence forces'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   "ukraine's national resistance centre"),
#  ('ukrainian president volodymyr zelensky', 'vladimir zelenskiy'),
#  ('defense forces of ukraine', 'ukrainian troops'),
#  ('ukraine military', "ukraine's armed forces"),
#  ('russian defence ministry', 'russian ministry of defence'),
#  ('vladimir zelenskiy', 'volodymyr zelensky'),
#  ("ukraine's military", 'ukrainian military'),
#  ('volodimir zelensky', 'volodymyr zelenskyj'),
#  ("russia's defense ministry", 'russian ministry of defence'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian center for national resistance'),
#  ('volodimir zelensky', 'wolodymyr selenskyj'),
#  ('defense forces of ukraine', "ukraine's armed forces"),
#  ('ukraine military', "ukraine's defense forces"),
#  ('center of national resistance of ukraine',
#   "ukraine's national resistance centre"),
#  ('armed forces of ukraine', "ukraine's armed forces"),
#  ('ukrainian army', 'ukrainian forces'),
#  ('ukrainian president volodymyr zelensky', 'volodimir zelensky'),
#  ('defense forces of ukraine', "ukraine's defense forces"),
#  ("ukraine's national resistance centre",
#   'ukrainian center of national resistance'),
#  ('britain', 'great britain'),
#  ('kremlin-installed officials', 'russian-appointed officials'),
#  ("ukraine's national resistance centre",
#   'ukrainian center for national resistance'),
#  ('centre of national resistance of the armed forces of ukraine',
#   "ukraine's national resistance center"),
#  ('russian defense ministry', 'russian ministry of defense'),
#  ('armed forces of ukraine', 'ukrainian forces'),
#  ('armed forces of ukraine', "ukraine's defense forces"),
#  ('centre of national resistance of the armed forces of ukraine',
#   'national resistance center of ukraine'),
#  ('ministry of defence of russia', 'russian ministry of defence'),
#  ('federal security service', 'fsb of russia'),
#  ('oleksander tarnawskyi', 'oleksandr tarnavskyi'),
#  ('luiz inacio lula da silva', 'luiz inácio lula da silva'),
#  ('ukrainian centre of national resistance',
#   'ukrainian national resistance center'),
#  ('oleksander tarnawskyi', 'olexander tarnawskyj'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'ukrainian center of national resistance'),
#  ('volodimir zelensky', 'volodymyr zelensky'),
#  ('ukrainian armed forces', 'ukrainian military'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'ukrainian center for national resistance'),
#  ('vladimir aleksandrovich zelensky', 'volodymyr zelenskiyy'),
#  ('ukrainian president volodymyr zelensky',
#   'vladimir aleksandrovich zelensky'),
#  ('oleksander tarnawskyi', 'oleksandr tarnavsky'),
#  ('brazilian president luiz inacio lula da silva', 'lula da silva'),
#  ('oleksander tarnavskyi', 'oleksander tarnawskyi'),
#  ('luis inacio lula da silva', 'luiz inácio lula da silva'),
#  ('vladimir zelenskiy', 'volodymyr zelenskiyy'),
#  ('russian defense ministry', 'russian mod'),
#  ('serhii borzov', 'serhiy borsov'),
#  ('oleksandr tarnavsky', 'oleksandr tarnawskyi'),
#  ('oleksandr tarnavsky', 'oleksandr tarnawski'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian center of national resistance'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian center for national resistance'),
#  ('uk government', 'united kingdom'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian centre of national resistance'),
#  ('wolodimir zelenski', 'wolodymyr selenskyj'),
#  ('volodymyr zelenskiyy', 'volodymyr zelenskyj'),
#  ('vladimir aleksandrovich zelensky', 'wolodimir zelenski'),
#  ('britain', 'united kingdom'),
#  ('oleksander tarnawskyi', 'oleksandr tarnavskiy'),
#  ('ukrainian president volodymyr zelensky', 'volodymyr zelenskyj'),
#  ('ukrainian president volodymyr zelensky', 'wolodymyr selenskyj'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'centre of national resistance of ukraine'),
#  ('center of national resistance of ukraine',
#   'ukrainian center of national resistance'),
#  ("ukraine's armed forces", 'ukrainian forces'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   "ukraine's national resistance center"),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'ukrainian center for national resistance'),
#  ('center of national resistance of ukraine',
#   'ukrainian center for national resistance'),
#  ('akhmat', 'akhmat grozny'),
#  ('britain', 'uk government'),
#  ('brazilian president luiz inacio lula da silva',
#   'luiz inacio lula da silva'),
#  ("ukraine's national resistance center",
#   'ukrainian national resistance center'),
#  ('ukrainian army', 'ukrainian defense forces'),
#  ('ministry of defense of russia', 'russian ministry of defence'),
#  ('volodimir zelensky', 'volodymyr zelenskiyy'),
#  ('armed forces of ukraine', 'ukrainian defense forces'),
#  ("russia's defence ministry", "russia's ministry of defence"),
#  ('abbas galiamov', 'abbas galljamov'),
#  ('vlodomyr zelensky', 'volodymyr zelenskyj'),
#  ('volodymyr zelensky', 'volodymyr zelenskyj'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   "ukraine's national resistance center"),
#  ('volodymyr zelensky', 'wolodymyr selenskyj'),
#  ('abbas galiyamov', 'abbas galljamov'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'national resistance center of ukraine'),
#  ('national resistance center of ukraine',
#   'ukrainian national resistance center'),
#  ('ukrainian president volodymyr zelensky', 'volodymyr zelensky'),
#  ('oleksander tarnavskyi', 'oleksandr tarnavskyi'),
#  ('oleksander tarnavskyi', 'olexander tarnawskyj'),
#  ('ukraine military', 'ukrainian defence forces'),
#  ('centre of national resistance of ukraine',
#   'national resistance center of ukraine'),
#  ('russia-installed officials', 'russian-installed authorities'),
#  ('roman starovoit', 'roman starovoyt'),
#  ('oleksander tarnavskyi', 'oleksandr tarnawskyj'),
#  ('vladimir zelenskiy', 'vlodomyr zelensky'),
#  ("centre national de la résistance d'ukraine",
#   'centre of national resistance of the armed forces of ukraine'),
#  ('vladimir aleksandrovich zelensky', 'volodimir zelenski'),
#  ('ukrainian army', 'ukrainian troops'),
#  ("russia's ministry of defence", 'russian ministry of defense'),
#  ('ukraine military', "ukraine's military"),
#  ('united nations high commissioner for human rights',
#   'united nations human rights council'),
#  ("russia's defence ministry", 'russian defense ministry'),
#  ('defense forces of ukraine', 'ukrainian defence forces'),
#  ('volodimir zelensky', 'wolodimir zelenski'),
#  ('abbas galiamov', 'abbas galyamov'),
#  ('forces armées ukrainiennes', "ukraine's armed forces"),
#  ('armed forces of ukraine', 'ukrainian troops'),
#  ("centre national de la résistance d'ukraine",
#   'ukrainian center of national resistance'),
#  ('ukraine military', 'ukrainian military'),
#  ('armed forces of ukraine', 'ukrainian defence forces'),
#  ('vladimir zelenskiy', 'volodimir zelenski'),
#  ('russian president vladimir putin', 'vladimir putin'),
#  ("centre national de la résistance d'ukraine",
#   'ukrainian center for national resistance'),
#  ("russia's defence ministry", 'russian ministry of defense'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'ukrainian centre of national resistance'),
#  ('forces armées ukrainiennes', 'ukrainian forces'),
#  ('forces armées ukrainiennes', "ukraine's defense forces"),
#  ('russian-appointed officials', 'russian-installed authorities'),
#  ('kremlin-installed officials', 'russian-installed officials'),
#  ('defense forces of ukraine', 'ukrainian military'),
#  ('centre of national resistance of ukraine',
#   'ukrainian centre of national resistance'),
#  ('ministry of defense of the russian federation',
#   "russia's ministry of defence"),
#  ('defense forces of ukraine', 'forces armées ukrainiennes'),
#  ('oleksander tarnavskyi', 'oleksandr tarnavskiy'),
#  ('volodimir zelenski', 'volodymyr zelenskyj'),
#  ("centre national de la résistance d'ukraine",
#   "ukraine's national resistance center"),
#  ('oleksii makeiev', 'oleksiy makeyev'),
#  ("centre national de la résistance d'ukraine",
#   'national resistance center of ukraine'),
#  ("russia's defence ministry", 'russian mod'),
#  ('ukrainian president volodymyr zelensky', 'volodymyr zelenskiyy'),
#  ('oleksander tarnawskyi', 'oleksandr tarnawskyj'),
#  ('volodymyr zelenskyj', 'wolodimir zelenski'),
#  ('ministry of defense of the russian federation', 'russian defense ministry'),
#  ('russian defense ministry', 'russian ministry of defence'),
#  ('ministry of defense of the russian federation',
#   'russian ministry of defense'),
#  ("ukraine's armed forces", 'ukrainian defence forces'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   "ukraine's national resistance center"),
#  ('vlodomyr zelensky', 'volodymyr zelenskiyy'),
#  ('oleksandr tarnavskiy', 'oleksandr tarnavsky'),
#  ('volodymyr zelenskiyy', 'wolodimir zelenski'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'national resistance center of ukraine'),
#  ("centre national de la résistance d'ukraine",
#   'ukrainian centre of national resistance'),
#  ('russian ministry of defence', 'russian ministry of defense'),
#  ('vladimir zelenskiy', 'volodimir zelensky'),
#  ('ukrainian armed forces', 'ukrainian forces'),
#  ('ukrainian president volodymyr zelensky', 'wolodimir zelenski'),
#  ('russia-installed officials', 'russian-installed officials'),
#  ('kremlin-installed officials', 'russia-installed officials'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'ukrainian national resistance center'),
#  ('centre of national resistance of ukraine',
#   'ukrainian national resistance center'),
#  ("centre national de la résistance d'ukraine",
#   'centre of national resistance of ukraine'),
#  ('oleksander tarnawskyi', 'oleksandr tarnawskyi'),
#  ('oleksander tarnawskyi', 'oleksandr tarnawski'),
#  ("ukraine's national resistance centre",
#   'ukrainian centre of national resistance'),
#  ('brazilian president luiz inacio lula da silva',
#   'luis inacio lula da silva'),
#  ('ministry of defense of the russian federation', 'russian mod'),
#  ('ukrainian center of national resistance',
#   'ukrainian national resistance center'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'national resistance center of ukraine'),
#  ('centre of national resistance of the armed forces of ukraine',
#   "ukraine's national resistance centre"),
#  ('vlodomyr zelensky', 'wolodimir zelenski'),
#  ('volodymyr zelensky', 'wolodimir zelenski'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'ukrainian centre of national resistance'),
#  ('abbas galiyamov', 'abbas gallyamov'),
#  ('vladimir aleksandrovich zelensky', 'vlodomyr zelensky'),
#  ("russia's defense ministry", "russia's ministry of defence"),
#  ('center of national resistance of ukraine',
#   "ukraine's national resistance center"),
#  ('center of national resistance of ukraine',
#   'national resistance center of ukraine'),
#  ('armed forces of ukraine', 'defense forces of ukraine'),
#  ('britain', 'british government'),
#  ('ukrainian president volodymyr zelensky', 'volodimir zelenski'),
#  ('vladimir zelenskiy', 'volodymyr zelenskyj'),
#  ("ukraine's national resistance center",
#   'ukrainian center of national resistance'),
#  ('forces armées ukrainiennes', 'ukrainian defence forces'),
#  ('vladimir zelenskiy', 'wolodymyr selenskyj'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian centre of national resistance'),
#  ("ukraine's national resistance center",
#   'ukrainian center for national resistance'),
#  ('ukrainian army', 'ukrainian defence forces'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian national resistance center'),
#  ('ministry of defence of russia', "russia's ministry of defence"),
#  ('brazilian president luiz inacio lula da silva',
#   'luiz inácio lula da silva'),
#  ('abbas galiamov', 'abbas galiyamov'),
#  ('russian defence ministry', 'russian ministry of defense'),
#  ('ukrainian armed forces', 'ukrainian defense forces'),
#  ('foreign ministry of moldova', 'moldovan foreign ministry'),
#  ('vlodomyr zelensky', 'volodimir zelenski'),
#  ("russia's defense ministry", 'russian ministry of defense'),
#  ('center of national resistance of ukraine',
#   'ukrainian centre of national resistance'),
#  ('national resistance center of ukraine',
#   'ukrainian center for national resistance'),
#  ("ukraine's national resistance centre",
#   'ukrainian national resistance center'),
#  ('ukrainian army', 'ukrainian military'),
#  ('volodimir zelenski', 'wolodimir zelenski'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ('armed forces of ukraine', 'ukrainian military'),
#  ('france', 'french government'),
#  ("russia's defence ministry", 'russian ministry of defence'),
#  ('oleksander tarnavskyi', 'oleksandr tarnawskyi'),
#  ('oleksandr tarnawski', 'oleksandr tarnawskyj'),
#  ('oleksander tarnavskyi', 'oleksandr tarnawski'),
#  ('armed forces of ukraine', 'forces armées ukrainiennes'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'ukrainian national resistance center'),
#  ("ukraine's military", 'ukrainian forces'),
#  ('centre of national resistance of the armed forces of ukraine',
#   'ukrainian center of national resistance'),
#  ('luis inacio lula da silva', 'luiz inacio lula da silva'),
#  ('russian defence ministry', 'russian mod'),
#  ('ukraine military', 'ukrainian forces'),
#  ("ukraine's defense forces", 'ukrainian forces'),
#  ('ministry of defence of russia', 'russian ministry of defense'),
#  ('oleksandr tarnavsky', 'oleksandr tarnavskyi'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   "ukraine's national resistance centre"),
#  ('ukrainian armed forces', 'ukrainian troops'),
#  ("russia's defense ministry", 'russian mod'),
#  ('british government', 'great britain'),
#  ('oleksandr tarnavsky', 'olexander tarnawskyj'),
#  ('ukrainian armed forces', 'ukrainian defence forces'),
#  ('centre of national resistance of ukraine',
#   "ukraine's national resistance centre"),
#  ('oleksandr tarnavsky', 'oleksandr tarnawskyj'),
#  ('defense forces of ukraine', 'ukrainian forces'),
#  ('national resistance center of the special operations of the ukrainian armed forces',
#   'ukrainian national resistance center'),
#  ('ministry of defense of russia', "russia's ministry of defence"),
#  ('great britain', 'uk government'),
#  ('ministry of defence of russia', 'russian mod'),
#  ('oleksandr tarnawski', 'oleksandr tarnawskyi'),
#  ('center of national resistance of ukraine',
#   'ukrainian national resistance center'),
#  ('ministry of defense of the russian federation',
#   'russian ministry of defence'),
#  ('ministry of defence of russia',
#   'ministry of defence of the russian federation'),
#  ('kremlin-installed officials', 'russian-installed authorities'),
#  ("centre national de la résistance d'ukraine",
#   "ukraine's national resistance centre"),
#  ("ukraine's military", 'ukrainian defense forces'),
#  ('ministry of defense of russia', 'russian ministry of defense'),
#  ('ukraine military', 'ukrainian defense forces'),
#  ('russian-appointed officials', 'russian-installed officials'),
#  ('ukrainian president volodymyr zelensky', 'vlodomyr zelensky'),
#  ('abbas gallyamov', 'abbas galyamov'),
#  ('british government', 'uk government'),
#  ('abbas galljamov', 'abbas gallyamov'),
#  ('vladimir aleksandrovich zelensky', 'volodymyr zelenskyj'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   'national resistance center of the special operations of the ukrainian armed forces'),
#  ("national resistance center of the special operations forces of ukraine's armed forces",
#   'ukrainian center of national resistance'),
#  ('vladimir aleksandrovich zelensky', 'wolodymyr selenskyj'),
#  ('vladimir zelenskiy', 'wolodimir zelenski'),
#  ('defense forces of ukraine', 'ukrainian defense forces'),
#  ('centre of national resistance of ukraine',
#   'ukrainian center of national resistance'),
#  ('centre of national resistance of ukraine',
#   'ukrainian center for national resistance'),
#  ('ukrainian center for national resistance',
#   'ukrainian national resistance center'),
#  ('ukraine military', 'ukrainian armed forces'),
#  ('russian defence ministry', 'russian defense ministry'),
#  ('national resistance center of the special operations forces of the armed forces of ukraine',
#   "ukraine's national resistance centre"),
#  ("centre national de la résistance d'ukraine",
#   'ukrainian national resistance center'),
#  ('ministry of defense of russia', 'russian mod')]

# %%
del itemid_to_wiki_info
